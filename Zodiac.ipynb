# %% [markdown]
# # Zodiac: Source Code and Documentation

# %% [markdown]
# ###### Date: May 30, 2016

# %% [markdown]
# Modern buildings consist of many different types of infrastructure such as lighting, air conditioning, power, water. For operation and maintenance of these systems with minimal manual supervision, networked sensors are deployed across the building so that it can be monitored remotely. <a href="https://en.wikipedia.org/wiki/Building_management_system"> Building Management Systems (BMS)</a> are software systems that collect data from installed sensors, allow remote control of equipment and provide visualizations for the maintenance personnel.
#
# Modern BMSes have thousands of data points per building, and these data points correspond to installed sensors, actuators of equipment as well as configuration parameters. With modern data processing and control mechanisms it is possible to exploit these data points to create useful and innovative building applications such as personalized control, fault detection, demand response management, model predictive control, power grid stability and many more. However, a major impediment to deployment of these applications is that the data points are organized for building domain experts and not computer algorithms. As a result, the metadata that describes the context of the data points in the BMS has errors, extraneous notes, vendor specific notations and other inconsistencies which make it difficult for a machine to interpret the data. Our project Zodiac exploits machine learning techniques to map the raw building metadata to a consistent format so that applications can be developed on top of a common interface and reused across multiple buildings.
#
# Our full research paper which describes the building metadata problem and the Zodiac algorithm can be found <a href="http://dl.acm.org/citation.cfm?id=2821674">here</a>. The Zodiac project home page where we share our raw building metadata, manually labelled ground truth data point types and this source code page can be found <a href="http://www.synergylabs.org/bharath/zodiac.html">here</a>.

# %% [markdown]
# ### Source Code

# %% [markdown]
# We are making the source code available using the Jupyter notebook with explanations alongside so it is easy to follow and replicate our results.
#
# #### Input File Paths
# The notebook code assumes that the raw metadata and manually labelled ground truth files are available in "metadata" directory at the same level as the notebook.
#
# #### Python Libraries
# We heavily use the <a href="http://scikit-learn.org/stable/">Python Scikit Learn</a> library, which contains implementations of popular machine learning algorithms such as hierarchical clustering and random forest classifier used in our algorithm. We use Python <a href="http://www.numpy.org/">numpy</a> and <a href="http://pandas.pydata.org/">pandas</a> libraries to store and manipulate large records of metadata. These data structures work well with Scikit Learn modules.
#
# We use Python <a href="https://docs.python.org/2/library/re.html">re</a> for regular expressions and <a href="http://matplotlib.org/">matplotlib</a> for plotting. We also use <a href="https://docs.python.org/2/library/shelve.html">shelve</a> and <a href="https://docs.python.org/2/library/pickle.html">pickle</a> for object serialization and non-volatile storage.

# %%
#essential libraries
import numpy as np
import pandas as pd
from scipy.cluster.vq import *
import operator
from matplotlib import pyplot as plt   
import pickle as pkl
import shelve
import re
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
import scipy
from sklearn.feature_extraction import DictVectorizer

# %% [markdown]
# The file "bacnet_devices.shelve" contains the building points metadata for about 55 buildings at <a href="http://ucsd.edu/">University of California, San Diego</a> (UCSD). We obtain this metadata using <a href="http://www.bacnet.org/">BACnet</a>, a standard building automation network communication protocol.
#
# When loaded, the shelve file becomes a Python dictionary. The format of the metadata is as follows:

# %% [raw]
# ### This is not part of the source code ####
# ["bacnet_device_id": {
#            "props":{ "device_id": 557 },
#            "objs":{
#                "sensor_1":{
#                    "props":{
#                        "type": 0,
#                        "type_str": "analog input", #BACnet encodes type as enumerator. 0 stands for analog input
#                        "instance": 230523
#                    },
#                    "name":"NAE 57 N2 1 VAV 5 ZN T",
#                    "source_id":"557_0_3001187", #Concatenation of device id, type and object instance
#                    "description":"Zone Temperature", #Human readable point description
#                    "unit": 64, #BACnet encoded units. 64 stands for Fahrenheit
#                    "jci_name": "BH.1STFLR.RM-1511.VAV-5.ZN-T"
#                }
#            }
#  },
#  "bacnet_device_id_2": {
#    ...
#  },
#  ...
# ]

# %% [markdown]
# The "bacnet_device_id" corresponds to a middlebox that hosts up to 4000 building data points. One building can be assigned several middleboxes based on its requiments and the network design. All of the 55 buildings we obtain our metadata from are managed by the vendor <a href="http://www.johnsoncontrols.com/">Johnson Control Inc.</a>, and some of the metadata organizing may be specific to this vendor.
#
# Each point is identified by its "instance" within the middlebox, and we define a "source_id" as a university wide unique identifier for the point. There are two names associated with the point. The "name" corresponds to BACnet name property, and the name is based on network architecture. The "jci_name" is a proprietary BACnet field used by Johnson Controls, and the name is assigned relative to building location hierarchy. The last part of the name ("ZN T" above) encodes an abbreviation of the data point type. The human readable data point type is given in "description" (e.g. "Zone Temperature").
#
# BACnet also encodes the data type and input/output in one field referred to as "type" above. For example, "analog input" means the data type is float and the point is of input type (e.g. sensor).

# %%
#Import shelve dictionary containing all bacnet devices
sensors_dict = shelve.open('metadata/bacnet_devices.shelve','r')

# %%
#device_list filters the NAE for a particular building. This is currently manual. It can be automated 
#if building names are known.

#bonner hall
device_list = [
                "557",
                "607",
                "608",
                "609",
                "610",
]

# %%
#Parse the data in the dictionary as filtered by device_list
#Gives us a sensor_list with sensor information of a building
sensor_list = []
names_list = []
names_listWithDigits = [] 
sensor_type_namez=[]
desc_list = []
unit_list = []
type_str_list = []
type_list = []
jci_names_list = []
source_id_set = set([])
for nae in device_list:
    device = sensors_dict[nae]
    h_dev = device['props']
    for sensor in device['objs']:
        h_obj = sensor['props']
        source_id = str(h_dev['device_id']) + '_' + str(h_obj['type']) + '_' + str(h_obj['instance'])
        
        if h_obj['type'] not in (0,1,2,3,4,5,13,14,19):
            continue
        
        if source_id in source_id_set:
            continue
        else:
            source_id_set.add(source_id)
        
        #create individual lists
        #remove numbers from names because they do not indicate type of sensor
        names_listWithDigits.append(sensor['jci_name']) 
        sensor_type_namez.append(sensor['sensor_type'])
        names_list.append(''.join([c for c in sensor['name'] if not c.isdigit()]))
        desc_list.append(''.join([c for c in sensor['desc'] if not c.isdigit()]))
        jci_names_list.append(''.join([c for c in sensor['jci_name'] if not c.isdigit()]))
        #convert string to dictionary for categorical vectorization
        unit_list.append({str(sensor['unit']):1})
        type_str_list.append({str(h_obj['type_str']):1})
        type_list.append({str(h_obj['type']):1})
        
        #create a flat list of dictionary to avoid using json file
        sensor_list.append({'source_id': source_id, 
                            'name': sensor['name'], 
                            'description': sensor['desc'],
                            'unit': sensor['unit'],
                            'type_string': h_obj['type_str'],
                            'type': h_obj['type'],
                            #'device_id': h_obj['device_id'],
                            'jci_name': sensor['jci_name'],
                            #add data related characteristics here
                        })
sensor_df = pd.DataFrame(sensor_list)
sensor_df = sensor_df.set_index('source_id')
sensor_df = sensor_df.groupby(sensor_df.index).first()
print len(sensor_list)
# Out:
# 3213

# %%
#Create a bag of words from sensor string metadata. Vectorize so that it can be used in ML algorithms.
namevect = CountVectorizer(token_pattern='(?u)\\b\\w+\\b')
namebow = scipy.sparse.coo_matrix(namevect.fit_transform(names_list))

descvect = CountVectorizer() 
descbow = scipy.sparse.coo_matrix(descvect.fit_transform(desc_list))

unitvect = DictVectorizer() 
unitbow = scipy.sparse.coo_matrix(unitvect.fit_transform(unit_list))

type_str_vect = DictVectorizer() 
type_str_bow = scipy.sparse.coo_matrix(type_str_vect.fit_transform(type_str_list))

typevect = DictVectorizer() 
typebow = scipy.sparse.coo_matrix(typevect.fit_transform(type_list))

jcivect = CountVectorizer() 
jcibow = scipy.sparse.coo_matrix(jcivect.fit_transform(jci_names_list))

feature_set = jcivect.get_feature_names()+ \
              descvect.get_feature_names()+ \
              unitvect.get_feature_names()+ \
              type_str_vect.get_feature_names()+ \
              typevect.get_feature_names()
              

final_bow = scipy.sparse.hstack([
                                 #namebow,
                                 descbow,
                                 unitbow,
                                 type_str_bow,
                                 typebow,
                                 jcibow
                                ]) 
bow_array = final_bow.toarray() # this is the bow for each sensor.

# %%
# Hierarchical agglomerative clustering 
from scipy.cluster.hierarchy import linkage, dendrogram
import scipy.cluster.hierarchy as hier

num_of_sensors = len(bow_array)
a = np.array(bow_array[:num_of_sensors])
z = linkage(a,metric='cityblock',method='complete')

# %%
#Apply threshold to hierarchical tree to obtain individual clusters. Results stored in equip_map
dists = list(set(z[:,2]))
thresh = (dists[2] + dists[3]) /2 
print "Threshold: ", thresh
b = hier.fcluster(z,thresh, criterion='distance')
cluster_map = {}
equip_map = {}
for i in range(len(b)):
    cluster_map[names_list[i]] = b[i]
    print i, names_list[i], b[i]
    if b[i] in equip_map:
        equip_map[b[i]]["sensors"].append(sensor_list[i])
        equip_map[b[i]]["sensor_ids"].append(i)
    else:
        equip_map[b[i]] = {"sensors":[sensor_list[i]]}
        equip_map[b[i]]["sensor_ids"] = [i]
    sensor_list[i]['equip_cluster_id'] = b[i]
sorted_map = sorted(cluster_map.items(), key=operator.itemgetter(1))
# Out:
# Threshold:  2.5
# 0 NAE  N  VAV  RMA T 246
# 1 NAE  N  VAV  EB T 243
# 2 NAE  N  VAV  EB T 243
# 3 NAE  N  VAV  RMA T 248
# 4 NAE  N  VAV  RA T 244
# 5 NAE  N  VAV  SA T 245
# 6 NAE  N  VAV  RA T 244
# 7 NAE  N  VAV  SA T 245
# 8 NAE  N  VAV  RA T 244
# 9 NAE  N  VAV  SA T 245
# 10 NAE  N  VAV  RA T 244
# 11 NAE  N  VAV  SA T 245
# 12 NAE  N  VAV  ZN T 95
# 13 NAE  N  VAV  WC ADJ 240
# 14 NAE  N  VAV  ACTCLG SP 241
# 15 NAE  N  VAV  ACTHTG SP 242
# 16 NAE  N  VAV  ZN T 95
# 17 NAE  N  VAV  WC ADJ 240
# 18 NAE  N  VAV  ACTCLG SP 241
# 19 NAE  N  VAV  ACTHTG SP 242
# 20 NAE  N  VAV  ZN T 95
# 21 NAE  N  VAV  WC ADJ 240
# 22 NAE  N  VAV  ACTCLG SP 241
# 23 NAE  N  VAV  ACTHTG SP 242
# 24 NAE  N  VAV  RA T 244
# 25 NAE  N  VAV  SA T 245
# 26 NAE  N  VAV  RA T 244
# 27 NAE  N  VAV  SA T 245
# 28 NAE  N  VAV  RA T 244
# 29 NAE  N  VAV  SA T 245
# 30 NAE  N  VAV  RA T 244
# 31 NAE  N  VAV  SA T 245
# 32 NAE  N  VAV  RA T 244
# 33 NAE  N  VAV  SA T 245
# 34 NAE  N  VAV  RA T 244
# 35 NAE  N  VAV  SA T 245
# 36 NAE  N  VAV  RA T 244
# 37 NAE  N  VAV  SA T 245
# 38 NAE  N  VAV  RA T 244
# 39 NAE  N  VAV  SA T 245
# 40 NAE  N  VAV  RA T 244
# 41 NAE  N  VAV  SA T 245
# 42 NAE  N  AHU  CHWR T 257
# 43 NAE  N  AHU  DA T 258
# 44 NAE  N  AHU  OA T 259
# 45 NAE  N  VAV  CB T 250
# 46 NAE  N  VAV  CB T 250
# 47 NAE  N  VAV  HB T 249
# 48 NAE  N  VAV  HB T 249
# 49 NAE  N  VAV  RMA T 247
# 50 NAE  N  VAV  CB T 250
# 51 NAE  N  AHU  SA FLOW 262
# 52 NAE  N  AHU  HTWS T 254
# 53 NAE  N  AHU  STM P 263
# 54 NAE  N  AHU  DA T 258
# 55 NAE  N  AHU  CHW DP 265
# 56 NAE  N  AHU  CHWR T 257
# 57 NAE  N  AHU  CHWR T 257
# 58 NAE  N  AHU  DA T 258
# 59 NAE  N  UNT  CB T 252
# 60 NAE  N  UNT  CB T 252
# 61 NAE  N  UNT  CBA T 252
# 62 NAE  N  UNT  B T 253
# 63 NAE  N  UNT  CBN T 252
# 64 NAE  N  UNT  CBS T 252
# 65 NAE  N  UNT  EB T 251
# 66 NAE  N  UNT  EB T 251
# 67 NAE  N  UNT  HTWR T 255
# 68 NAE  N  UNT  MTWS T 256
# 69 NAE  N  UNT  STM T 264
# 70 NAE  N  DX  EF  SP 184
# 71 NAE  N  DX  EF  VP 185
# 72 NAE  N  DX  EF  SP 184
# 73 NAE  N  DX  EF  VP 185
# 74 NAE  N  DX  EF  SP 184
# 75 NAE  N  DX  EF  VP 185
# 76 NAE  N  DX  EF  SP 184
# 77 NAE  N  DX  EF  VP 185
# 78 NAE  N  DX  EF  SP 184
# 79 NAE  N  DX  EF  VP 185
# 80 NAE  N  DX  EF  SP 184
# 81 NAE  N  DX  EF  VP 185
# 82 NAE  N  DX  EF  SP 184
# 83 NAE  N  DX  EF  VP 185
# 84 NAE  N  DX  EF  SP 184
# 85 NAE  N  DX  EF  VP 185
# 86 NAE  N  DX  EF  SP 184
# 87 NAE  N  DX  EF  VP 185
# 88 NAE  N  DX  EF  SP 184
# 89 NAE  N  DX  EF  VP 185
# 90 NAE  N  DX  EF  SP 184
# 91 NAE  N  DX  EF  VP 185
# 92 NAE  N  VFD  FREQ 175
# 93 NAE  N  VFD  SPD REF 172
# 94 NAE  N  VFD  VFD AMP 174
# 95 NAE  N  VFD  VOLTS 176
# 96 NAE  N  VFD  PWR KW 177
# 97 NAE  N  VFD  RUN HRS 179
# 98 NAE  N  VFD  KW HRS 180
# 99 NAE  N  VFD  MW HRS 178
# 100 NAE  N  VFD  DRIVE T 173
# 101 NAE  N  VFD  RPM 171
# 102 NAE  N  VFD  FREQ 175
# 103 NAE  N  VFD  SPD REF 172
# 104 NAE  N  VFD  VFD AMP 174
# 105 NAE  N  VFD  VOLTS 176
# 106 NAE  N  VFD  PWR KW 177
# 107 NAE  N  VFD  RUN HRS 179
# 108 NAE  N  VFD  KW HRS 180
# 109 NAE  N  VFD  MW HRS 178
# 110 NAE  N  VFD  DRIVE T 173
# 111 NAE  N  VFD  RPM 171
# 112 NAE  N  VFD  FREQ 175
# 113 NAE  N  VFD  SPD REF 172
# 114 NAE  N  VFD  VFD AMP 174
# 115 NAE  N  VFD  VOLTS 176
# 116 NAE  N  VFD  PWR KW 177
# 117 NAE  N  VFD  RUN HRS 179
# 118 NAE  N  VFD  KW HRS 180
# 119 NAE  N  VFD  MW HRS 178
# 120 NAE  N  VFD  DRIVE T 173
# 121 NAE  N  VFD  RPM 171
# 122 NAE  N  VFD  FREQ 175
# 123 NAE  N  VFD  SPD REF 172
# 124 NAE  N  VFD  VFD AMP 174
# 125 NAE  N  VFD  VOLTS 176
# 126 NAE  N  VFD  PWR KW 177
# 127 NAE  N  VFD  RUN HRS 179
# 128 NAE  N  VFD  KW HRS 180
# 129 NAE  N  VFD  MW HRS 178
# 130 NAE  N  VFD  DRIVE T 173
# 131 NAE  N  VFD  RPM 171
# 132 NAE  N  AHU  SA SP 260
# 133 NAE  N  AHU  SA SP 261
# 134 NAE  N  AHU  DI Water Level 266
# 135 NAE  N  AHU  DAT SP 225
# 136 NAE  N  VAV  CLG CMD 203
# 137 NAE  N  VAV  HTGVLV CMD 204
# 138 NAE  N  VAV  CLG SP 230
# 139 NAE  N  VAV  HTG SP 231
# 140 NAE  N  VAV  CLG CMD 203
# 141 NAE  N  VAV  HTGVLV CMD 204
# 142 NAE  N  VAV  CLG SP 230
# 143 NAE  N  VAV  HTG SP 231
# 144 NAE  N  VAV  CLG CMD 203
# 145 NAE  N  VAV  HTGVLV CMD 204
# 146 NAE  N  VAV  CLG SP 230
# 147 NAE  N  VAV  HTG SP 231
# 148 NAE  N  VAV  CLG CMD 203
# 149 NAE  N  VAV  HTGVLV CMD 204
# 150 NAE  N  VAV  CLG SP 230
# 151 NAE  N  VAV  HTG SP 231
# 152 NAE  N  VAV  CLG CMD 206
# 153 NAE  N  VAV  HTGVLV CMD 207
# 154 NAE  N  VAV  CLG SP 226
# 155 NAE  N  VAV  HTG SP 228
# 156 NAE  N  VAV  UNOCCCLG SP 227
# 157 NAE  N  VAV  UNOCCHTG SP 229
# 158 NAE  N  VAV  CLG CMD 206
# 159 NAE  N  VAV  HTGVLV CMD 207
# 160 NAE  N  VAV  CLG SP 226
# 161 NAE  N  VAV  HTG SP 228
# 162 NAE  N  VAV  UNOCCCLG SP 227
# 163 NAE  N  VAV  UNOCCHTG SP 229
# 164 NAE  N  VAV  CLG CMD 206
# 165 NAE  N  VAV  HTGVLV CMD 207
# 166 NAE  N  VAV  CLG SP 226
# 167 NAE  N  VAV  HTG SP 228
# 168 NAE  N  VAV  UNOCCCLG SP 227
# 169 NAE  N  VAV  UNOCCHTG SP 229
# 170 NAE  N  VAV  CLG CMD 203
# 171 NAE  N  VAV  HTGVLV CMD 204
# 172 NAE  N  VAV  CLG SP 230
# 173 NAE  N  VAV  HTG SP 231
# 174 NAE  N  VAV  CLG CMD 203
# 175 NAE  N  VAV  HTGVLV CMD 204
# 176 NAE  N  VAV  CLG SP 230
# 177 NAE  N  VAV  HTG SP 231
# 178 NAE  N  VAV  HTGVLV CMD 204
# 179 NAE  N  VAV  CLG SP 230
# 180 NAE  N  VAV  HTG SP 231
# 181 NAE  N  VAV  HTGVLV CMD 204
# 182 NAE  N  VAV  CLG SP 230
# 183 NAE  N  VAV  HTG SP 231
# 184 NAE  N  VAV  HTGVLV CMD 204
# 185 NAE  N  VAV  CLG SP 230
# 186 NAE  N  VAV  HTG SP 231
# 187 NAE  N  VAV  HTGVLV CMD 204
# 188 NAE  N  VAV  CLG SP 230
# 189 NAE  N  VAV  HTG SP 231
# 190 NAE  N  VAV  CLG CMD 203
# 191 NAE  N  VAV  HTGVLV CMD 204
# 192 NAE  N  VAV  CLG SP 230
# 193 NAE  N  VAV  HTG SP 231
# 194 NAE  N  VAV  HTGVLV CMD 204
# 195 NAE  N  VAV  CLG SP 230
# 196 NAE  N  VAV  HTG SP 231
# 197 NAE  N  VAV  HTGVLV CMD 204
# 198 NAE  N  VAV  CLG SP 230
# 199 NAE  N  VAV  HTG SP 231
# 200 NAE  N  AHU  CLGVLV CMD 200
# 201 NAE  N  AHU  HTGVLV CMD 201
# 202 NAE  N  VAV  DIGLREAD 205
# 203 NAE  N  VAV  DIGLREAD 205
# 204 NAE  N  VAV  DIGLREAD 205
# 205 NAE  N  VAV  DIGLREAD 205
# 206 NAE  N  VAV  DIGLREAD 205
# 207 NAE  N  VAV  DIGLREAD 205
# 208 NAE  N  AHU  DAT SP 225
# 209 NAE  N  AHU  SAFLOW SP 212
# 210 NAE  N  AHU  DAT SP 225
# 211 NAE  N  UNT  HX SP 232
# 212 NAE  N  AHU  CLGVLV CMD 200
# 213 NAE  N  AHU  FLOW CMD 210
# 214 NAE  N  AHU  HTGVLV CMD 201
# 215 NAE  N  AHU  CHWDP SP 214
# 216 NAE  N  AHU  CHWP CMD 211
# 217 NAE  N  AHU  CLGVLV CMD 200
# 218 NAE  N  AHU  HTGVLV CMD 201
# 219 NAE  N  UNT  HEVLV CMD 202
# 220 NAE  N  AHU  Tuning CLG IT 223
# 221 NAE  N  AHU  Tuning CLG PB 238
# 222 NAE  N  AHU  Tuning HTG IT 219
# 223 NAE  N  AHU  Tuning HTG PB 234
# 224 NAE  N  VAV  Tuning CLG PB 239
# 225 NAE  N  VAV  Tuning CLG IT 224
# 226 NAE  N  VAV  Tuning HTG PB 235
# 227 NAE  N  VAV  Tuning HTG IT 220
# 228 NAE  N  VAV  Tuning CLG PB 239
# 229 NAE  N  VAV  Tuning CLG IT 224
# 230 NAE  N  VAV  Tuning HTG PB 235
# 231 NAE  N  VAV  Tuning HTG IT 220
# 232 NAE  N  VAV  Tuning CLG PB 239
# 233 NAE  N  VAV  Tuning CLG IT 224
# 234 NAE  N  VAV  Tuning HTG PB 235
# 235 NAE  N  VAV  Tuning HTG IT 220
# 236 NAE  N  VAV  Tuning CLG PB 239
# 237 NAE  N  VAV  Tuning CLG IT 224
# 238 NAE  N  VAV  Tuning HTG PB 235
# 239 NAE  N  VAV  Tuning HTG IT 220
# 240 NAE  N  VAV  Tuning HTG PB 236
# 241 NAE  N  VAV  Tuning HTG IT 221
# 242 NAE  N  VAV  Tuning CLG PB 237
# 243 NAE  N  VAV  Tuning CLG IT 222
# 244 NAE  N  VAV  Tuning HTG PB 236
# 245 NAE  N  VAV  Tuning HTG IT 221
# 246 NAE  N  VAV  Tuning CLG PB 237
# 247 NAE  N  VAV  Tuning CLG IT 222
# 248 NAE  N  VAV  Tuning HTG PB 236
# 249 NAE  N  VAV  Tuning HTG IT 221
# 250 NAE  N  VAV  Tuning CLG PB 237
# 251 NAE  N  VAV  Tuning CLG IT 222
# 252 NAE  N  VAV  Tuning CLG PB 239
# 253 NAE  N  VAV  Tuning CLG IT 224
# 254 NAE  N  VAV  Tuning HTG PB 235
# 255 NAE  N  VAV  Tuning HTG IT 220
# 256 NAE  N  VAV  Tuning CLG PB 239
# 257 NAE  N  VAV  Tuning CLG IT 224
# 258 NAE  N  VAV  Tuning HTG PB 235
# 259 NAE  N  VAV  Tuning HTG IT 220
# 260 NAE  N  VAV  Tuning CLG PB 239
# 261 NAE  N  VAV  Tuning CLG IT 224
# 262 NAE  N  VAV  Tuning HTG PB 235
# 263 NAE  N  VAV  Tuning HTG IT 220
# 264 NAE  N  VAV  Tuning CLG PB 239
# 265 NAE  N  VAV  Tuning CLG IT 224
# 266 NAE  N  VAV  Tuning HTG PB 235
# 267 NAE  N  VAV  Tuning HTG IT 220
# 268 NAE  N  VAV  Tuning CLG PB 239
# 269 NAE  N  VAV  Tuning CLG IT 224
# 270 NAE  N  VAV  Tuning HTG PB 235
# 271 NAE  N  VAV  Tuning HTG IT 220
# 272 NAE  N  VAV  Tuning CLG PB 239
# 273 NAE  N  VAV  Tuning CLG IT 224
# 274 NAE  N  VAV  Tuning HTG PB 235
# 275 NAE  N  VAV  Tuning HTG IT 220
# 276 NAE  N  VAV  Tuning CLG PB 239
# 277 NAE  N  VAV  Tuning CLG IT 224
# 278 NAE  N  VAV  Tuning HTG PB 235
# 279 NAE  N  VAV  Tuning HTG IT 220
# 280 NAE  N  VAV  Tuning CLG PB 239
# 281 NAE  N  VAV  Tuning CLG IT 224
# 282 NAE  N  VAV  Tuning HTG PB 235
# 283 NAE  N  VAV  Tuning HTG IT 220
# 284 NAE  N  VAV  Tuning CLG PB 239
# 285 NAE  N  VAV  Tuning CLG IT 224
# 286 NAE  N  VAV  Tuning HTG PB 235
# 287 NAE  N  VAV  Tuning HTG IT 220
# 288 NAE  N  AHU  Tuning CLG IT 223
# 289 NAE  N  AHU  Tuning CLG PB 238
# 290 NAE  N  AHU  Tuning HTG IT 219
# 291 NAE  N  AHU  Tuning HTG PB 234
# 292 NAE  N  AHU  Tuning SAFLOW IT 218
# 293 NAE  N  AHU  Tuning SAFLOW PB 213
# 294 NAE  N  AHU  Tuning CLG IT 223
# 295 NAE  N  AHU  Tuning CLG PB 238
# 296 NAE  N  AHU  Tuning HTG IT 219
# 297 NAE  N  AHU  Tuning HTG PB 234
# 298 NAE  N  UNT  Tuning HX PB 233
# 299 NAE  N  UNT  Tuning HX IT 216
# 300 NAE  N  AHU  Tuning CHWDP IT 217
# 301 NAE  N  AHU  Tuning CHWDP PB 215
# 302 NAE  N  DX  EF  SPSTPT 189
# 303 NAE  N  DX  EF  VFDCMD 191
# 304 NAE  N  DX  EF  VPSTPT 190
# 305 NAE  N  DX  EF  BYPDMP 192
# 306 NAE  N  DX  EF  SPSTPT 189
# 307 NAE  N  DX  EF  VFDCMD 191
# 308 NAE  N  DX  EF  VPSTPT 190
# 309 NAE  N  DX  EF  BYPDMP 192
# 310 NAE  N  DX  EF  SPSTPT 189
# 311 NAE  N  DX  EF  VFDCMD 191
# 312 NAE  N  DX  EF  VPSTPT 190
# 313 NAE  N  DX  EF  BYPDMP 192
# 314 NAE  N  DX  Tunning EF  SPPB 187
# 315 NAE  N  DX  Tunning EF  SPTI 186
# 316 NAE  N  DX  Tunning EF  SPEDB 188
# 317 NAE  N  DX  Tunning EF  VPPB 187
# 318 NAE  N  DX  Tunning EF  VPTI 186
# 319 NAE  N  DX  Tunning EF  VPEDB 188
# 320 NAE  N  DX  Tunning EF  SPPB 187
# 321 NAE  N  DX  Tunning EF  SPTI 186
# 322 NAE  N  DX  Tunning EF  SPEDB 188
# 323 NAE  N  DX  Tunning EF  VPPB 187
# 324 NAE  N  DX  Tunning EF  VPTI 186
# 325 NAE  N  DX  Tunning EF  VPEDB 188
# 326 NAE  N  DX  Tunning EF  SPPB 187
# 327 NAE  N  DX  Tunning EF  SPTI 186
# 328 NAE  N  DX  Tunning EF  SPEDB 188
# 329 NAE  N  DX  Tunning EF  VPPB 187
# 330 NAE  N  DX  Tunning EF  VPTI 186
# 331 NAE  N  DX  Tunning EF  VPEDB 188
# 332 NAE  N  DX  EF  SPSTPT 189
# 333 NAE  N  DX  EF  VFDCMD 191
# 334 NAE  N  DX  EF  VPSTPT 190
# 335 NAE  N  DX  EF  BYPDMP 192
# 336 NAE  N  DX  EF  SPSTPT 189
# 337 NAE  N  DX  EF  VFDCMD 191
# 338 NAE  N  DX  EF  VPSTPT 190
# 339 NAE  N  DX  EF  BYPDMP 192
# 340 NAE  N  DX  EF  SPSTPT 189
# 341 NAE  N  DX  EF  VFDCMD 191
# 342 NAE  N  DX  EF  VPSTPT 190
# 343 NAE  N  DX  EF  BYPDMP 192
# 344 NAE  N  DX  EF  SPSTPT 189
# 345 NAE  N  DX  EF  VFDCMD 191
# 346 NAE  N  DX  EF  VPSTPT 190
# 347 NAE  N  DX  EF  BYPDMP 192
# 348 NAE  N  DX  EF  SPSTPT 189
# 349 NAE  N  DX  EF  VFDCMD 191
# 350 NAE  N  DX  EF  VPSTPT 190
# 351 NAE  N  DX  EF  BYPDMP 192
# 352 NAE  N  DX  Tunning EF  SPPB 187
# 353 NAE  N  DX  Tunning EF  SPTI 186
# 354 NAE  N  DX  Tunning EF  SPEDB 188
# 355 NAE  N  DX  Tunning EF  VPPB 187
# 356 NAE  N  DX  Tunning EF  VPTI 186
# 357 NAE  N  DX  Tunning EF  VPEDB 188
# 358 NAE  N  DX  Tunning EF  SPPB 187
# 359 NAE  N  DX  Tunning EF  SPTI 186
# 360 NAE  N  DX  Tunning EF  SPEDB 188
# 361 NAE  N  DX  Tunning EF  VPPB 187
# 362 NAE  N  DX  Tunning EF  VPTI 186
# 363 NAE  N  DX  Tunning EF  VPEDB 188
# 364 NAE  N  DX  Tunning EF  SPPB 187
# 365 NAE  N  DX  Tunning EF  SPTI 186
# 366 NAE  N  DX  Tunning EF  SPEDB 188
# 367 NAE  N  DX  Tunning EF  VPPB 187
# 368 NAE  N  DX  Tunning EF  VPTI 186
# 369 NAE  N  DX  Tunning EF  VPEDB 188
# 370 NAE  N  DX  Tunning EF  SPPB 187
# 371 NAE  N  DX  Tunning EF  SPTI 186
# 372 NAE  N  DX  Tunning EF  SPEDB 188
# 373 NAE  N  DX  Tunning EF  VPPB 187
# 374 NAE  N  DX  Tunning EF  VPTI 186
# 375 NAE  N  DX  Tunning EF  VPEDB 188
# 376 NAE  N  DX  Tunning EF  SPPB 187
# 377 NAE  N  DX  Tunning EF  SPTI 186
# 378 NAE  N  DX  Tunning EF  SPEDB 188
# 379 NAE  N  DX  Tunning EF  VPPB 187
# 380 NAE  N  DX  Tunning EF  VPTI 186
# 381 NAE  N  DX  Tunning EF  VPEDB 188
# 382 NAE  N  DX  EF  SPSTPT 189
# 383 NAE  N  DX  EF VFD 191
# 384 NAE  N  DX  EF  VPSTPT 190
# 385 NAE  N  DX  EF BYP 192
# 386 NAE  N  DX  EF  SPSTPT 189
# 387 NAE  N  DX  EF VFD 191
# 388 NAE  N  DX  EF  VPSTPT 190
# 389 NAE  N  DX  EF BYP 192
# 390 NAE  N  DX  EF  SPSTPT 189
# 391 NAE  N  DX  EF VFD 191
# 392 NAE  N  DX  EF  VPSTPT 190
# 393 NAE  N  DX  EF BYP 192
# 394 NAE  N  DX  Tunning EF  SPPB 187
# 395 NAE  N  DX  Tunning EF  SPTI 186
# 396 NAE  N  DX  Tunning EF  SPEDB 188
# 397 NAE  N  DX  Tunning EF  VPPB 187
# 398 NAE  N  DX  Tunning EF  VPTI 186
# 399 NAE  N  DX  Tunning EF  VPEDB 188
# 400 NAE  N  DX  Tunning EF  SPPB 187
# 401 NAE  N  DX  Tunning EF  SPTI 186
# 402 NAE  N  DX  Tunning EF  SPEDB 188
# 403 NAE  N  DX  Tunning EF  VPPB 187
# 404 NAE  N  DX  Tunning EF  VPTI 186
# 405 NAE  N  DX  Tunning EF  VPEDB 188
# 406 NAE  N  DX  Tunning EF  SPPB 187
# 407 NAE  N  DX  Tunning EF  SPTI 186
# 408 NAE  N  DX  Tunning EF  SPEDB 188
# 409 NAE  N  DX  Tunning EF  VPPB 187
# 410 NAE  N  DX  Tunning EF  VPTI 186
# 411 NAE  N  DX  Tunning EF  VPEDB 188
# 412 NAE  N  AHU  SFVFD CMD 208
# 413 NAE  N  AHU  SASP SET 196
# 414 NAE  N  AHU  Tuning SASP PB 193
# 415 NAE  N  AHU  Tuning SASP IT 195
# 416 NAE  N  AHU  Tuning SASP DB 194
# 417 NAE  N  AHU  SASP STPT 196
# 418 NAE  N  AHU  SFVFD CMD 209
# 419 NAE  N  AHU  Tuning SASP PB 197
# 420 NAE  N  AHU  Tuning SASP IT 199
# 421 NAE  N  AHU  Tuning SASP DB 198
# 422 NAE  Programming Analog Data BHPLANT HTW ON 289
# 423 NAE  Programming Analog Data BHPLANT HTW OFF 290
# 424 NAE  Programming Analog Data BHPLANT FUL HEAT 291
# 425 NAE  Programming Analog Data BHPLANT HE OSAH 285
# 426 NAE  Programming Analog Data BHPLANT HE OSAL 286
# 427 NAE  Programming Analog Data BHPLANT HE LO 287
# 428 NAE  Programming Analog Data BHPLANT HE HI 288
# 429 NAE  Programming Analog Data BHAHU  COLD ZON 301
# 430 NAE  Programming Analog Data BHAHU  WARM ZON 302
# 431 NAE  Programming Analog Data BHAHU  HI ZNCLG 292
# 432 NAE  Programming Analog Data BHAHU  LO DASP 295
# 433 NAE  Programming Analog Data BHAHU  HI DASP 296
# 434 NAE  Programming Analog Data BHRH AHU HICMD 293
# 435 NAE  Programming Analog Data BHRH AHU WMZN 297
# 436 NAE  Programming Analog Data BHRH AHU CDZN 298
# 437 NAE  Programming Analog Data BHRH AHU HICMD 293
# 438 NAE  Programming Analog Data BHRH AHU WMZN 297
# 439 NAE  Programming Analog Data BHRH AHU CDZN 298
# 440 NAE  Programming Analog Data BHBAR AHU  HICMD 294
# 441 NAE  Programming Analog Data BHBAR AHU  WMZN 299
# 442 NAE  Programming Analog Data BHBAR AHU  CDZN 300
# 443 NAE  Programming Analog Data BHRH AHU  HICMD 293
# 444 NAE  Programming Analog Data BHRH AHU  WMZN 297
# 445 NAE  Programming Analog Data BHRH AHU  CDZN 298
# 446 NAE  Programming Analog Data BHRH AHU  HICMD 293
# 447 NAE  Programming Analog Data BHRH AHU  WMZN 297
# 448 NAE  Programming Analog Data BHRH AHU  CDZN 298
# 449 NAE  Programming Analog Data BHAHU  COLD ZON 301
# 450 NAE  Programming Analog Data BHAHU  WARM ZON 302
# 451 NAE  Programming Analog Data BHAHU  HI ZNCLG 292
# 452 NAE  Programming Analog Data BHAHU  LO DASP 295
# 453 NAE  Programming Analog Data BHAHU  HI DASP 296
# 454 NAE  Programming Analog Data BHRH AHU HICMD 293
# 455 NAE  Programming Analog Data BHRH AHU WMZN 299
# 456 NAE  Programming Analog Data BHRH AHU CDZN 300
# 457 NAE  Programming Analog Data BHRH AHU HICMD 293
# 458 NAE  Programming Analog Data BHRH AHU WMZN 299
# 459 NAE  Programming Analog Data BHRH AHU CDZN 300
# 460 NAE  Programming Analog Data BHRH AHU HICMD 293
# 461 NAE  Programming Analog Data BHRH AHU WMZN 299
# 462 NAE  Programming Analog Data BHRH AHU CDZN 300
# 463 NAE  Programming Analog Data BHRH AHU HICMD 293
# 464 NAE  Programming Analog Data BHRH AHU WMZN 299
# 465 NAE  Programming Analog Data BHRH AHU CDZN 300
# 466 NAE  Programming Analog Data BHAHU  COLD ZON 301
# 467 NAE  Programming Analog Data BHAHU  WARM ZON 302
# 468 NAE  Programming Analog Data BHAHU  HI ZNCLG 292
# 469 NAE  Programming Analog Data BHAHU  LO DASP 295
# 470 NAE  Programming Analog Data BHAHU  HI DASP 296
# 471 NAE  Programming AHU  SA T Reset SATRST HI 271
# 472 NAE  Programming AHU  SA T Reset SATRST LO 271
# 473 NAE  Programming AHU  SA T Reset CLGRST HI 272
# 474 NAE  Programming AHU  SA T Reset CLGRST LO 272
# 475 NAE  Programming AHU  SA T Reset Hi Zone 270
# 476 NAE  Programming AHU  SA T Reset Low Zone 270
# 477 NAE  Programming AHU  SA T Reset Avg Zone 270
# 478 NAE  Programming AHU  SA T Reset SATRST HI 271
# 479 NAE  Programming AHU  SA T Reset SATRST LO 271
# 480 NAE  Programming AHU  SA T Reset CLGRST HI 272
# 481 NAE  Programming AHU  SA T Reset CLGRST LO 272
# 482 NAE  Programming AHU  SA T Reset Hi Zone 270
# 483 NAE  Programming AHU  SA T Reset Low Zone 270
# 484 NAE  Programming AHU  SA T Reset Avg Zone 270
# 485 NAE  N  VAV  OCC STS 152
# 486 NAE  N  VAV  TOCC STS 153
# 487 NAE  N  VAV  OCC STS 152
# 488 NAE  N  VAV  TOCC STS 153
# 489 NAE  N  VAV  OCC STS 152
# 490 NAE  N  VAV  TOCC STS 153
# 491 NAE  N  AHU  SMK ALM 162
# 492 NAE  N  AHU  SF STS 147
# 493 NAE  N  AHU  SF STS 147
# 494 NAE  N  AHU  FLTR STS 148
# 495 NAE  N  VAV  EF STS 151
# 496 NAE  N  VAV  DI COND 154
# 497 NAE  N  XT  AH OFF 155
# 498 NAE  N  XT  AH ON 156
# 499 NAE  N  XT  AH OFF 155
# 500 NAE  N  XT  AH ON 156
# 501 NAE  N  XT  AH OFF 155
# 502 NAE  N  XT  AH ON 156
# 503 NAE  N  XT  EF OFF 157
# 504 NAE  N  XT  EF ON 158
# 505 NAE  N  XT  EF OFF 157
# 506 NAE  N  XT  EF ON 158
# 507 NAE  N  XT  EF OFF 157
# 508 NAE  N  XT  EF ON 158
# 509 NAE  N  XT  EF OFF 157
# 510 NAE  N  XT  EF ON 158
# 511 NAE  N  XT  EF OFF 157
# 512 NAE  N  XT  EF ON 158
# 513 NAE  N  XT  EF OFF 157
# 514 NAE  N  XT  EF ON 158
# 515 NAE  N  XT  EF OFF 157
# 516 NAE  N  XT  EF ON 158
# 517 NAE  N  XT  EF OFF 157
# 518 NAE  N  XT  EF ON 158
# 519 NAE  N  XT  EF OFF 157
# 520 NAE  N  XT  EF ON 158
# 521 NAE  N  XT  EF OFF 157
# 522 NAE  N  XT  EF ON 158
# 523 NAE  N  XT  EF OFF 157
# 524 NAE  N  XT  EF ON 158
# 525 NAE  N  XT  EF OFF 157
# 526 NAE  N  XT  EF ON 158
# 527 NAE  N  XT  EF OFF 157
# 528 NAE  N  XT  EF ON 158
# 529 NAE  N  XT  EF OFF 157
# 530 NAE  N  XT  EF ON 158
# 531 NAE  N  XT  EF OFF 157
# 532 NAE  N  XT  EF ON 158
# 533 NAE  N  XT  EF OFF 157
# 534 NAE  N  XT  EF ON 158
# 535 NAE  N  XT  EF OFF 157
# 536 NAE  N  XT  EF ON 158
# 537 NAE  N  XT  EF ON 158
# 538 NAE  N  XT  TEST BTN 159
# 539 NAE  N  AHU  EMGN ALM 160
# 540 NAE  N  AHU  EMGN STS 161
# 541 NAE  N  AHU  FLTR STS 148
# 542 NAE  N  AHU  SF STS 147
# 543 NAE  N  AHU  CHWP STS 146
# 544 NAE  N  AHU  SMK ALM 163
# 545 NAE  N  AHU  SF STS 147
# 546 NAE  N  AHU  SF STS 147
# 547 NAE  N  AHU  PFLTR STS 149
# 548 NAE  N  UNT  EF STS 150
# 549 NAE  N  UNT  EF STS 150
# 550 NAE  N  UNT  EF STS 150
# 551 NAE  N  UNT  EF STS 150
# 552 NAE  N  UNT  EF STS 150
# 553 NAE  N  UNT  EF STS 150
# 554 NAE  N  UNT  EF STS 150
# 555 NAE  N  UNT  EF STS 150
# 556 NAE  N  UNT  EF STS 150
# 557 NAE  N  UNT  EF STS 150
# 558 NAE  N  UNT  SUMPLVL ALM 164
# 559 NAE  N  UNT  P STS 145
# 560 NAE  N  UNT  P STS 145
# 561 NAE  N  XT  EF OFF 157
# 562 NAE  N  DX  EF  STS 181
# 563 NAE  N  DX  EF  STS 181
# 564 NAE  N  DX  EF  STS 181
# 565 NAE  N  DX  EF  STS 181
# 566 NAE  N  DX  EF  STS 181
# 567 NAE  N  DX  EF  STS 181
# 568 NAE  N  DX  EF  STS 181
# 569 NAE  N  DX  EF  STS 181
# 570 NAE  N  DX  EF STS 181
# 571 NAE  N  DX  EF STS 181
# 572 NAE  N  DX  EF STS 181
# 573 NAE  N  VFD  RUN ENB 166
# 574 NAE  N  VFD  VFD STS 169
# 575 NAE  N  VFD  HAND AUTO 168
# 576 NAE  N  VFD  FLT STS 170
# 577 NAE  N  VFD  ALARM 167
# 578 NAE  N  VFD  MAIN REQ 165
# 579 NAE  N  VFD  RUN ENB 166
# 580 NAE  N  VFD  VFD STS 169
# 581 NAE  N  VFD  HAND AUTO 168
# 582 NAE  N  VFD  FLT STS 170
# 583 NAE  N  VFD  ALARM 167
# 584 NAE  N  VFD  MAIN REQ 165
# 585 NAE  N  VFD  RUN ENB 166
# 586 NAE  N  VFD  VFD STS 169
# 587 NAE  N  VFD  HAND AUTO 168
# 588 NAE  N  VFD  FLT STS 170
# 589 NAE  N  VFD  ALARM 167
# 590 NAE  N  VFD  MAIN REQ 165
# 591 NAE  N  VFD  RUN ENB 166
# 592 NAE  N  VFD  VFD STS 169
# 593 NAE  N  VFD  HAND AUTO 168
# 594 NAE  N  VFD  FLT STS 170
# 595 NAE  N  VFD  ALARM 167
# 596 NAE  N  VFD  MAIN REQ 165
# 597 NAE  N  VAV  HF SS 106
# 598 NAE  N  VAV  HF SS 106
# 599 NAE  N  VAV  HF SS 106
# 600 NAE  N  VAV  HF SS 106
# 601 NAE  N  VAV  HF SS 106
# 602 NAE  N  AHU  FAN EXT 125
# 603 NAE  N  AHU  FAN RET 126
# 604 NAE  N  AHU  FAN EXT 125
# 605 NAE  N  AHU  FAN RET 126
# 606 NAE  N  VAV  OCC CMD 119
# 607 NAE  N  VAV  OCC CMD 119
# 608 NAE  N  VAV  OCC CMD 119
# 609 NAE  N  VAV  OCC CMD 119
# 610 NAE  N  VAV  OCC CMD 118
# 611 NAE  N  VAV  OCC CMD 118
# 612 NAE  N  VAV  OCC CMD 118
# 613 NAE  N  VAV  OCC CMD 119
# 614 NAE  N  VAV  OCC CMD 119
# 615 NAE  N  VAV  OCC CMD 119
# 616 NAE  N  VAV  OCC CMD 119
# 617 NAE  N  VAV  OCC CMD 119
# 618 NAE  N  VAV  OCC CMD 119
# 619 NAE  N  VAV  OCC CMD 119
# 620 NAE  N  VAV  OCC CMD 119
# 621 NAE  N  VAV  OCC CMD 119
# 622 NAE  N  AHU  SF SS 124
# 623 NAE  N  AHU  SF SS 124
# 624 NAE  N  AHU  SDWN CMD 117
# 625 NAE  N  VAV  EF SS 109
# 626 NAE  N  VAV  HFB SS 107
# 627 NAE  N  XT  AH LOFF 110
# 628 NAE  N  XT  AH LON 111
# 629 NAE  N  XT  AH LOFF 110
# 630 NAE  N  XT  AH LON 111
# 631 NAE  N  XT  AH LOFF 110
# 632 NAE  N  XT  AH LON 111
# 633 NAE  N  XT  EF LOFF 112
# 634 NAE  N  XT  EF LON 113
# 635 NAE  N  XT  EF LOFF 112
# 636 NAE  N  XT  EF LON 113
# 637 NAE  N  XT  EF LOFF 112
# 638 NAE  N  XT  EF LON 113
# 639 NAE  N  XT  EF LOFF 112
# 640 NAE  N  XT  EF LON 113
# 641 NAE  N  XT  EF LOFF 112
# 642 NAE  N  XT  EF LON 113
# 643 NAE  N  XT  EF LOFF 112
# 644 NAE  N  XT  EF LON 113
# 645 NAE  N  XT  EF LOFF 112
# 646 NAE  N  XT  EF LON 113
# 647 NAE  N  XT  EF LOFF 112
# 648 NAE  N  XT  EF LON 113
# 649 NAE  N  XT  EF LOFF 112
# 650 NAE  N  XT  EF LON 113
# 651 NAE  N  XT  EF LOFF 112
# 652 NAE  N  XT  EF LON 113
# 653 NAE  N  XT  EF LOFF 112
# 654 NAE  N  XT  EF LON 113
# 655 NAE  N  XT  EF LOFF 112
# 656 NAE  N  XT  EF LON 113
# 657 NAE  N  XT  EF LOFF 112
# 658 NAE  N  XT  EF LON 113
# 659 NAE  N  XT  EF LOFF 112
# 660 NAE  N  XT  EF LON 113
# 661 NAE  N  XT  EF LOFF 112
# 662 NAE  N  XT  EF LON 113
# 663 NAE  N  XT  EF LOFF 112
# 664 NAE  N  XT  EF LON 113
# 665 NAE  N  XT  EF LOFF 112
# 666 NAE  N  XT  EF LON 113
# 667 NAE  N  XT  EF LOFF 112
# 668 NAE  N  XT  EF LON 113
# 669 NAE  N  AHU  FAN EXT 125
# 670 NAE  N  AHU  FAN RET 126
# 671 NAE  N  AHU  FAN EXT 125
# 672 NAE  N  AHU  FAN RET 126
# 673 NAE  N  AHU  FAN EXT 125
# 674 NAE  N  AHU  FAN RET 126
# 675 NAE  N  UNT  SDWN CMD 117
# 676 NAE  N  AHU  CHWP SS 115
# 677 NAE  N  AHU  AH FCOFF 122
# 678 NAE  N  AHU  AH FCON 123
# 679 NAE  N  AHU  SF SS 124
# 680 NAE  N  AHU  SDWN CMD 117
# 681 NAE  N  AHU  AH FCOFF 122
# 682 NAE  N  AHU  AH FCON 123
# 683 NAE  N  AHU  SF SS 124
# 684 NAE  N  AHU  SF SS 124
# 685 NAE  N  AHU  SDWN CMD 117
# 686 NAE  N  UNT  EF FCOFF 120
# 687 NAE  N  UNT  EF FCON 121
# 688 NAE  N  UNT  EF FCOFF 120
# 689 NAE  N  UNT  EF FCON 121
# 690 NAE  N  UNT  EF SS 108
# 691 NAE  N  UNT  EF SS 108
# 692 NAE  N  UNT  EF FCOFF 120
# 693 NAE  N  UNT  EF FCON 121
# 694 NAE  N  UNT  EF FCOFF 120
# 695 NAE  N  UNT  EF FCON 121
# 696 NAE  N  UNT  EF FCOFF 120
# 697 NAE  N  UNT  EF FCON 121
# 698 NAE  N  UNT  EF FCOFF 120
# 699 NAE  N  UNT  EF FCON 121
# 700 NAE  N  UNT  EF FCOFF 120
# 701 NAE  N  UNT  EF FCON 121
# 702 NAE  N  UNT  EF FCOFF 120
# 703 NAE  N  UNT  EF FCON 121
# 704 NAE  N  UNT  EF FCOFF 120
# 705 NAE  N  UNT  EF FCON 121
# 706 NAE  N  UNT  EF SS 108
# 707 NAE  N  UNT  EF FCOFF 120
# 708 NAE  N  UNT  EF FCON 121
# 709 NAE  N  UNT  EF FCOFF 120
# 710 NAE  N  UNT  EF FCON 121
# 711 NAE  N  UNT  EF FCOFF 120
# 712 NAE  N  UNT  EF FCON 121
# 713 NAE  N  UNT  EF FCOFF 120
# 714 NAE  N  UNT  EF FCON 121
# 715 NAE  N  UNT  EF SS 108
# 716 NAE  N  UNT  EF FCOFF 120
# 717 NAE  N  UNT  EF FCON 121
# 718 NAE  N  UNT  EF FCOFF 120
# 719 NAE  N  UNT  EF FCON 121
# 720 NAE  N  UNT  EF SS 108
# 721 NAE  N  UNT  EF SS 108
# 722 NAE  N  UNT  EF SS 108
# 723 NAE  N  UNT  EF FCOFF 120
# 724 NAE  N  UNT  EF FCON 121
# 725 NAE  N  UNT  EF FCOFF 120
# 726 NAE  N  UNT  EF FCON 121
# 727 NAE  N  UNT  EF SS 108
# 728 NAE  N  UNT  EF SS 108
# 729 NAE  N  UNT  EF SS 108
# 730 NAE  N  UNT  P SS 114
# 731 NAE  N  UNT  P SS 114
# 732 NAE  N  UNT  PUMPS STS 116
# 733 NAE  N  AHU  AH FCOFF 122
# 734 NAE  N  AHU  AH FCON 123
# 735 NAE  N  DX  EF  SYSENB 182
# 736 NAE  N  DX  EF  SS 183
# 737 NAE  N  DX  EF  SYSENB 182
# 738 NAE  N  DX  EF  SS 183
# 739 NAE  N  DX  EF  SYSENB 182
# 740 NAE  N  DX  EF  SS 183
# 741 NAE  N  DX  EF  SYSENB 182
# 742 NAE  N  DX  EF  SS 183
# 743 NAE  N  DX  EF  SYSENB 182
# 744 NAE  N  DX  EF  SS 183
# 745 NAE  N  DX  EF  SYSENB 182
# 746 NAE  N  DX  EF  SS 183
# 747 NAE  N  DX  EF  SYSENB 182
# 748 NAE  N  DX  EF  SS 183
# 749 NAE  N  DX  EF  SYSENB 182
# 750 NAE  N  DX  EF  SS 183
# 751 NAE  N  DX  EF  SYSENB 182
# 752 NAE  N  DX  EF  SS 183
# 753 NAE  N  DX  EF  SYSENB 182
# 754 NAE  N  DX  EF  SS 183
# 755 NAE  N  DX  EF  SYSENB 182
# 756 NAE  N  DX  EF  SS 183
# 757 NAE  Programming Binary Data BHAHU  FAN CALL 127
# 758 NAE  Programming Binary Data BHRH AHU  FNCL 128
# 759 NAE  Programming Binary Data BHRH AHU  FNCL 128
# 760 NAE  Programming Binary Data BHRH AHU  FNCL 128
# 761 NAE  Programming Pumps EVEN MONTH 137
# 762 NAE  Programming Binary Data BHPLANT HE SYS 144
# 763 NAE  Programming Binary Data BHRH AHU FNCL 130
# 764 NAE  Programming Binary Data BHRH AHU FNCL 128
# 765 NAE  Programming Binary Data BHRH AHU FNCL 129
# 766 NAE  Programming Binary Data BHRH AHU FNCL 128
# 767 NAE  Programming Binary Data BHAHU  FAN CALL 127
# 768 NAE  Programming FIREPANEL EF  TEST BTN 138
# 769 NAE  FC  AH SAV  ZN T 98
# 770 NAE  FC  AH SAV  ZN T 98
# 771 NAE  FC  AH SAV  ZN T 98
# 772 NAE  FC  AH SAV  ZN T 98
# 773 NAE  FC  AH SAV  ZN T 98
# 774 NAE  FC  AH SAV  ZN T 98
# 775 NAE  FC  AH SAV  ZN T 98
# 776 NAE  FC  AH SAV  ZN T 98
# 777 NAE  FC  AH SAV  ZN T 98
# 778 NAE  FC  AH FEC  ZN T 98
# 779 NAE  FC  AH FEC  SA FLOW 57
# 780 NAE  FC  AH FEC  EA FLOW 58
# 781 NAE  FC  AH FEC  FUME FLOW 56
# 782 NAE  FC  AH FEC  FUME SASH 93
# 783 NAE  FC  AH SAV  ZN T 98
# 784 NAE  FC  AH VMA  ZN T 98
# 785 NAE  FC  AH VMA  SA T 48
# 786 NAE  FC  EF  VMA  EA VP 53
# 787 NAE  FC  AH SAV  ZN T 98
# 788 NAE  FC  AH FEC  ZN T 98
# 789 NAE  FC  AH FEC  SA FLOW 57
# 790 NAE  FC  AH FEC  FUME FLOW 56
# 791 NAE  FC  AH FEC  FUME SASH 93
# 792 NAE  FC  AH FEC  ZN T 98
# 793 NAE  FC  AH FEC  SA FLOW 57
# 794 NAE  FC  AH FEC  EA FLOW 58
# 795 NAE  FC  AH FEC  FUME FLOW 56
# 796 NAE  FC  AH FEC  FUME SASH 93
# 797 NAE  FC  AH FEC  ZN T 98
# 798 NAE  FC  AH FEC  SA FLOW 57
# 799 NAE  FC  AH FEC  EA FLOW 58
# 800 NAE  FC  AH FEC  FUME FLOW 56
# 801 NAE  FC  AH FEC  FUME SASH 93
# 802 NAE  FC  AH VMA  ZN T 98
# 803 NAE  FC  AH VMA  SA T 48
# 804 NAE  FC  EF  VMA  EA VP 53
# 805 NAE  FC  AH SAV  ZN T 98
# 806 NAE  FC  AH SAV  ZN T 98
# 807 NAE  FC  AH SAV  ZN T 98
# 808 NAE  FC  AH SAV  ZN T 98
# 809 NAE  FC  AH SAV  ZN T 98
# 810 NAE  FC  AH FEC  ZN T 98
# 811 NAE  FC  AH FEC  SA FLOW 57
# 812 NAE  FC  AH FEC  EA FLOW 58
# 813 NAE  FC  AH FEC  FUME FLOW 56
# 814 NAE  FC  AH FEC  FUME SASH 93
# 815 NAE  FC  AH VMA  ZN T 98
# 816 NAE  FC  AH VMA  SA T 48
# 817 NAE  FC  EFX VMA  EA VP 53
# 818 NAE  FC  AH VMA  ZN T 98
# 819 NAE  FC  AH VMA  SA T 48
# 820 NAE  FC  EFX VMA  EA VP 52
# 821 NAE  FC  AH SAV  ZN T 98
# 822 NAE  FC  AH SAV  ZN T 98
# 823 NAE  FC  AH VMA  ZN T 98
# 824 NAE  FC  AH VMA  SA T 48
# 825 NAE  FC  EFX VMA  EA VP 53
# 826 NAE  FC  AH VMA  ZN T 98
# 827 NAE  FC  AH VMA  SA T 48
# 828 NAE  FC  AH VMA  ZN T 98
# 829 NAE  FC  AH VMA  SA T 48
# 830 NAE  FC  AH SAV  ZN T 98
# 831 NAE  FC  AH VMA  ZN T 98
# 832 NAE  FC  AH VMA  SA T 48
# 833 NAE  FC  EFX VMA  EA VP 53
# 834 NAE  FC  EFX VMA  EA VP 53
# 835 NAE  FC  AH VMA  ZN T 98
# 836 NAE  FC  AH VMA  SA T 48
# 837 NAE  FC  AH SAV  ZN T 98
# 838 NAE  FC  AH SAV  ZN T 98
# 839 NAE  FC  AH VMA  ZN T 98
# 840 NAE  FC  AH VMA  SA T 48
# 841 NAE  FC  AH FEC  SA FLOW 57
# 842 NAE  FC  AH FEC  EA FLOW 58
# 843 NAE  FC  AH FEC  FUME FLOW 56
# 844 NAE  FC  AH FEC  FUME SASH 93
# 845 NAE  FC  EFX VMA  EA VP 53
# 846 NAE  FC  AH VMA  ZN T 98
# 847 NAE  FC  AH VMA  SA T 48
# 848 NAE  FC  AH SAV  HTGVLV CMD 60
# 849 NAE  FC  AH SAV  HTGVLV CMD 60
# 850 NAE  FC  AH SAV  HTGVLV CMD 60
# 851 NAE  FC  AH SAV  HTGVLV CMD 60
# 852 NAE  FC  AH SAV  HTGVLV CMD 60
# 853 NAE  FC  AH SAV  HTGVLV CMD 60
# 854 NAE  FC  AH SAV  HTGVLV CMD 60
# 855 NAE  FC  AH SAV  HTGVLV CMD 60
# 856 NAE  FC  AH SAV  HTGVLV CMD 60
# 857 NAE  FC  AH FEC  HTGVLV CMD 60
# 858 NAE  FC  AH SAV  HTGVLV CMD 60
# 859 NAE  FC  AH VMA  DPR CMD 67
# 860 NAE  FC  AH VMA  HTGVLV CMD 60
# 861 NAE  FC  EF  VMA  DPR CMD 67
# 862 NAE  FC  AH SAV  HTGVLV CMD 60
# 863 NAE  FC  AH FEC  HTGVLV CMD 60
# 864 NAE  FC  AH FEC  HTGVLV CMD 60
# 865 NAE  FC  AH FEC  HTGVLV CMD 61
# 866 NAE  FC  AH VMA  DPR CMD 65
# 867 NAE  FC  AH VMA  HTGVLV CMD 61
# 868 NAE  FC  EF  VMA  DPR CMD 65
# 869 NAE  FC  AH SAV  HTGVLV CMD 61
# 870 NAE  FC  AH SAV  HTGVLV CMD 61
# 871 NAE  FC  AH SAV  HTGVLV CMD 61
# 872 NAE  FC  AH SAV  HTGVLV CMD 61
# 873 NAE  FC  AH SAV  HTGVLV CMD 61
# 874 NAE  FC  AH FEC  HTGVLV CMD 61
# 875 NAE  FC  AH VMA  DPR CMD 65
# 876 NAE  FC  AH VMA  HTGVLV CMD 61
# 877 NAE  FC  EFX VMA  DPR CMD 65
# 878 NAE  FC  AH VMA  DPR CMD 65
# 879 NAE  FC  AH VMA  HTGVLV CMD 61
# 880 NAE  FC  EFX VMA  DPR CMD 65
# 881 NAE  FC  AH SAV  HTGVLV CMD 61
# 882 NAE  FC  AH SAV  HTGVLV CMD 61
# 883 NAE  FC  AH VMA  DPR CMD 65
# 884 NAE  FC  AH VMA  HTGVLV CMD 61
# 885 NAE  FC  EFX VMA  DPR CMD 65
# 886 NAE  FC  AH VMA  DPR CMD 65
# 887 NAE  FC  AH VMA  HTGVLV CMD 61
# 888 NAE  FC  AH VMA  DPR CMD 65
# 889 NAE  FC  AH VMA  HTGVLV CMD 61
# 890 NAE  FC  AH SAV  HTGVLV CMD 61
# 891 NAE  FC  AH VMA  DPR CMD 65
# 892 NAE  FC  AH VMA  HTGVLV CMD 61
# 893 NAE  FC  EFX VMA  DPR CMD 65
# 894 NAE  FC  EFX VMA  DPR CMD 65
# 895 NAE  FC  AH VMA  DPR CMD 65
# 896 NAE  FC  AH VMA  HTGVLV CMD 61
# 897 NAE  FC  AH SAV  HTGVLV CMD 61
# 898 NAE  FC  AH SAV  HTGVLV CMD 61
# 899 NAE  FC  AH VMA  DPR CMD 65
# 900 NAE  FC  AH VMA  HTGVLV CMD 61
# 901 NAE  FC  AH FEC  HTGVLV CMD 61
# 902 NAE  FC  EFX VMA  DPR CMD 65
# 903 NAE  FC  AH VMA  DPR CMD 65
# 904 NAE  FC  AH VMA  HTGVLV CMD 61
# 905 NAE  FC  AH FEC  PHX CMD 69
# 906 NAE  FC  AH SAV  ZN STPT 101
# 907 NAE  FC  AH SAV  ACTCLG STPT 14
# 908 NAE  FC  AH SAV  ACTHTG STPT 16
# 909 NAE  FC  AH SAV  COM STPT 20
# 910 NAE  FC  AH SAV  HTG DMD 38
# 911 NAE  FC  AH SAV  CLG DMD 40
# 912 NAE  FC  AH SAV  OCCCLG DB 25
# 913 NAE  FC  AH SAV  OCCHTG DB 28
# 914 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 915 NAE  FC  AH SAV  UNLOCK CODE 32
# 916 NAE  FC  AH SAV  ZN STPT 101
# 917 NAE  FC  AH SAV  ACTCLG STPT 14
# 918 NAE  FC  AH SAV  ACTHTG STPT 16
# 919 NAE  FC  AH SAV  COM STPT 20
# 920 NAE  FC  AH SAV  HTG DMD 38
# 921 NAE  FC  AH SAV  CLG DMD 40
# 922 NAE  FC  AH SAV  OCCCLG DB 25
# 923 NAE  FC  AH SAV  OCCHTG DB 28
# 924 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 925 NAE  FC  AH SAV  UNLOCK CODE 32
# 926 NAE  FC  AH SAV  ZN STPT 101
# 927 NAE  FC  AH SAV  ACTCLG STPT 14
# 928 NAE  FC  AH SAV  ACTHTG STPT 16
# 929 NAE  FC  AH SAV  COM STPT 20
# 930 NAE  FC  AH SAV  HTG DMD 38
# 931 NAE  FC  AH SAV  CLG DMD 40
# 932 NAE  FC  AH SAV  OCCCLG DB 25
# 933 NAE  FC  AH SAV  OCCHTG DB 28
# 934 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 935 NAE  FC  AH SAV  UNLOCK CODE 32
# 936 NAE  FC  AH SAV  ZN STPT 101
# 937 NAE  FC  AH SAV  ACTCLG STPT 14
# 938 NAE  FC  AH SAV  ACTHTG STPT 16
# 939 NAE  FC  AH SAV  COM STPT 20
# 940 NAE  FC  AH SAV  HTG DMD 38
# 941 NAE  FC  AH SAV  CLG DMD 40
# 942 NAE  FC  AH SAV  OCCCLG DB 25
# 943 NAE  FC  AH SAV  OCCHTG DB 28
# 944 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 945 NAE  FC  AH SAV  UNLOCK CODE 32
# 946 NAE  FC  AH SAV  ZN STPT 101
# 947 NAE  FC  AH SAV  ACTCLG STPT 14
# 948 NAE  FC  AH SAV  ACTHTG STPT 16
# 949 NAE  FC  AH SAV  COM STPT 20
# 950 NAE  FC  AH SAV  HTG DMD 38
# 951 NAE  FC  AH SAV  CLG DMD 40
# 952 NAE  FC  AH SAV  OCCCLG DB 25
# 953 NAE  FC  AH SAV  OCCHTG DB 28
# 954 NAE  FC  AH SAV  UNLOCK CODE 32
# 955 NAE  FC  AH SAV  ZN STPT 101
# 956 NAE  FC  AH SAV  ACTCLG STPT 14
# 957 NAE  FC  AH SAV  ACTHTG STPT 16
# 958 NAE  FC  AH SAV  COM STPT 20
# 959 NAE  FC  AH SAV  HTG DMD 38
# 960 NAE  FC  AH SAV  CLG DMD 40
# 961 NAE  FC  AH SAV  OCCCLG DB 25
# 962 NAE  FC  AH SAV  OCCHTG DB 28
# 963 NAE  FC  AH SAV  UNLOCK CODE 32
# 964 NAE  FC  AH SAV  ZN STPT 101
# 965 NAE  FC  AH SAV  ACTCLG STPT 14
# 966 NAE  FC  AH SAV  ACTHTG STPT 16
# 967 NAE  FC  AH SAV  COM STPT 20
# 968 NAE  FC  AH SAV  HTG DMD 38
# 969 NAE  FC  AH SAV  CLG DMD 40
# 970 NAE  FC  AH SAV  OCCCLG DB 25
# 971 NAE  FC  AH SAV  OCCHTG DB 28
# 972 NAE  FC  AH SAV  UNLOCK CODE 32
# 973 NAE  FC  AH SAV  ZN STPT 101
# 974 NAE  FC  AH SAV  ACTCLG STPT 14
# 975 NAE  FC  AH SAV  ACTHTG STPT 16
# 976 NAE  FC  AH SAV  COM STPT 20
# 977 NAE  FC  AH SAV  HTG DMD 38
# 978 NAE  FC  AH SAV  CLG DMD 40
# 979 NAE  FC  AH SAV  OCCCLG DB 25
# 980 NAE  FC  AH SAV  OCCHTG DB 28
# 981 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 982 NAE  FC  AH SAV  EXHFLOW FEEDBACK 4
# 983 NAE  FC  AH SAV  UNLOCK CODE 32
# 984 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 985 NAE  FC  AH SAV  EXHFLOW FEEDBACK 4
# 986 NAE  FC  AH SAV  UNLOCK CODE 32
# 987 NAE  FC  EF  EAV  UNLOCK CODE 32
# 988 NAE  FC  AH SAV  ZN STPT 101
# 989 NAE  FC  AH SAV  ACTCLG STPT 14
# 990 NAE  FC  AH SAV  ACTHTG STPT 16
# 991 NAE  FC  AH SAV  COM STPT 20
# 992 NAE  FC  AH SAV  HTG DMD 38
# 993 NAE  FC  AH SAV  CLG DMD 40
# 994 NAE  FC  AH SAV  OCCCLG DB 25
# 995 NAE  FC  AH SAV  OCCHTG DB 28
# 996 NAE  FC  AH SAV  UNLOCK CODE 32
# 997 NAE  FC  AH FEC  WC ADJ 42
# 998 NAE  FC  AH FEC  SAFLOW STPT 8
# 999 NAE  FC  AH FEC  CLG CMD 45
# 1000 NAE  FC  AH FEC  COM STPT 20
# 1001 NAE  FC  AH FEC  ACTCLG STPT 14
# 1002 NAE  FC  AH FEC  ACTHTG STPT 16
# 1003 NAE  FC  AH SAV  ZN STPT 101
# 1004 NAE  FC  AH SAV  ACTCLG STPT 14
# 1005 NAE  FC  AH SAV  ACTHTG STPT 16
# 1006 NAE  FC  AH SAV  COM STPT 20
# 1007 NAE  FC  AH SAV  HTG DMD 38
# 1008 NAE  FC  AH SAV  CLG DMD 40
# 1009 NAE  FC  AH SAV  OCCCLG DB 25
# 1010 NAE  FC  AH SAV  OCCHTG DB 28
# 1011 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 1012 NAE  FC  AH SAV  EXHFLOW FEEDBACK 4
# 1013 NAE  FC  AH SAV  UNLOCK CODE 32
# 1014 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 1015 NAE  FC  AH SAV  EXHFLOW FEEDBACK 4
# 1016 NAE  FC  AH SAV  UNLOCK CODE 32
# 1017 NAE  FC  EF  EAV  UNLOCK CODE 32
# 1018 NAE  FC  AH VMA  WC ADJ 42
# 1019 NAE  FC  AH VMA  SA FLOW 49
# 1020 NAE  FC  AH VMA  SAFLOW STPT 8
# 1021 NAE  FC  AH VMA  CLG CMD 45
# 1022 NAE  FC  AH VMA  COM STPT 20
# 1023 NAE  FC  AH VMA  ACTCLG STPT 14
# 1024 NAE  FC  AH VMA  ACTHTG STPT 16
# 1025 NAE  FC  EF  VMA  ZN T 103
# 1026 NAE  FC  EF  VMA  EA FLOW 55
# 1027 NAE  FC  EF  VMA  EAFLOW STPT 10
# 1028 NAE  FC  AH SAV  ZN STPT 101
# 1029 NAE  FC  AH SAV  ACTCLG STPT 14
# 1030 NAE  FC  AH SAV  ACTHTG STPT 16
# 1031 NAE  FC  AH SAV  COM STPT 20
# 1032 NAE  FC  AH SAV  HTG DMD 38
# 1033 NAE  FC  AH SAV  CLG DMD 40
# 1034 NAE  FC  AH SAV  OCCCLG DB 25
# 1035 NAE  FC  AH SAV  OCCHTG DB 28
# 1036 NAE  FC  AH SAV  UNLOCK CODE 32
# 1037 NAE  FC  AH FEC  WC ADJ 42
# 1038 NAE  FC  AH FEC  CLG CMD 45
# 1039 NAE  FC  AH FEC  COM STPT 20
# 1040 NAE  FC  AH FEC  ACTCLG STPT 14
# 1041 NAE  FC  AH FEC  ACTHTG STPT 16
# 1042 NAE  FC  AH FEC  WC ADJ 42
# 1043 NAE  FC  AH FEC  SAFLOW STPT 8
# 1044 NAE  FC  AH FEC  CLG CMD 45
# 1045 NAE  FC  AH FEC  COM STPT 20
# 1046 NAE  FC  AH FEC  ACTCLG STPT 14
# 1047 NAE  FC  AH FEC  ACTHTG STPT 16
# 1048 NAE  FC  AH FEC  WC ADJ 42
# 1049 NAE  FC  AH FEC  COM STPT 21
# 1050 NAE  FC  AH FEC  ACTCLG STPT 14
# 1051 NAE  FC  AH FEC  ACTHTG STPT 16
# 1052 NAE  FC  AH FEC  CLG CMD 46
# 1053 NAE  FC  AH FEC  SAFLOW STPT 8
# 1054 NAE  FC  AH VMA  WC ADJ 42
# 1055 NAE  FC  AH VMA  SA FLOW 49
# 1056 NAE  FC  AH VMA  SAFLOW STPT 8
# 1057 NAE  FC  AH VMA  CLG CMD 46
# 1058 NAE  FC  AH VMA  COM STPT 21
# 1059 NAE  FC  AH VMA  ACTCLG STPT 14
# 1060 NAE  FC  AH VMA  ACTHTG STPT 16
# 1061 NAE  FC  EF  VMA  ZN T 103
# 1062 NAE  FC  EF  VMA  EA FLOW 55
# 1063 NAE  FC  EF  VMA  EAFLOW STPT 10
# 1064 NAE  FC  AH SAV  ZN STPT 101
# 1065 NAE  FC  AH SAV  ACTCLG STPT 14
# 1066 NAE  FC  AH SAV  ACTHTG STPT 16
# 1067 NAE  FC  AH SAV  COM STPT 21
# 1068 NAE  FC  AH SAV  HTG DMD 38
# 1069 NAE  FC  AH SAV  CLG DMD 40
# 1070 NAE  FC  AH SAV  OCCCLG DB 25
# 1071 NAE  FC  AH SAV  OCCHTG DB 28
# 1072 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 1073 NAE  FC  AH SAV  EXHFLOW FEEDBACK 4
# 1074 NAE  FC  AH SAV  UNLOCK CODE 33
# 1075 NAE  FC  AH SAV  ZN STPT 101
# 1076 NAE  FC  AH SAV  ACTCLG STPT 14
# 1077 NAE  FC  AH SAV  ACTHTG STPT 16
# 1078 NAE  FC  AH SAV  COM STPT 21
# 1079 NAE  FC  AH SAV  HTG DMD 38
# 1080 NAE  FC  AH SAV  CLG DMD 40
# 1081 NAE  FC  AH SAV  OCCCLG DB 25
# 1082 NAE  FC  AH SAV  OCCHTG DB 28
# 1083 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 1084 NAE  FC  AH SAV  UNLOCK CODE 33
# 1085 NAE  FC  AH SAV  ZN STPT 101
# 1086 NAE  FC  AH SAV  ACTCLG STPT 14
# 1087 NAE  FC  AH SAV  ACTHTG STPT 16
# 1088 NAE  FC  AH SAV  COM STPT 21
# 1089 NAE  FC  AH SAV  HTG DMD 38
# 1090 NAE  FC  AH SAV  CLG DMD 40
# 1091 NAE  FC  AH SAV  OCCCLG DB 25
# 1092 NAE  FC  AH SAV  OCCHTG DB 28
# 1093 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 1094 NAE  FC  AH SAV  EXHFLOW FEEDBACK 4
# 1095 NAE  FC  AH SAV  UNLOCK CODE 33
# 1096 NAE  FC  EFX EAV  EXHFLOW FEEDBACK 5
# 1097 NAE  FC  EFX EAV  UNLOCK CODE 33
# 1098 NAE  FC  AH SAV  ZN STPT 101
# 1099 NAE  FC  AH SAV  ACTCLG STPT 14
# 1100 NAE  FC  AH SAV  ACTHTG STPT 16
# 1101 NAE  FC  AH SAV  COM STPT 21
# 1102 NAE  FC  AH SAV  HTG DMD 38
# 1103 NAE  FC  AH SAV  CLG DMD 40
# 1104 NAE  FC  AH SAV  OCCCLG DB 25
# 1105 NAE  FC  AH SAV  OCCHTG DB 28
# 1106 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 1107 NAE  FC  AH SAV  EXHFLOW FEEDBACK 4
# 1108 NAE  FC  AH SAV  UNLOCK CODE 33
# 1109 NAE  FC  AH SAV  ZN STPT 101
# 1110 NAE  FC  AH SAV  ACTCLG STPT 14
# 1111 NAE  FC  AH SAV  ACTHTG STPT 16
# 1112 NAE  FC  AH SAV  COM STPT 21
# 1113 NAE  FC  AH SAV  HTG DMD 38
# 1114 NAE  FC  AH SAV  CLG DMD 40
# 1115 NAE  FC  AH SAV  OCCCLG DB 25
# 1116 NAE  FC  AH SAV  OCCHTG DB 28
# 1117 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 1118 NAE  FC  AH SAV  EXHFLOW FEEDBACK 4
# 1119 NAE  FC  AH SAV  UNLOCK CODE 33
# 1120 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 1121 NAE  FC  AH SAV  UNLOCK CODE 33
# 1122 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 1123 NAE  FC  AH SAV  UNLOCK CODE 33
# 1124 NAE  FC  EFX EAV  UNLOCK CODE 33
# 1125 NAE  FC  AH FEC  WC ADJ 42
# 1126 NAE  FC  AH FEC  COM STPT 21
# 1127 NAE  FC  AH FEC  ACTCLG STPT 14
# 1128 NAE  FC  AH FEC  ACTHTG STPT 16
# 1129 NAE  FC  AH FEC  CLG CMD 46
# 1130 NAE  FC  AH FEC  SAFLOW STPT 8
# 1131 NAE  FC  AH VMA  WC ADJ 42
# 1132 NAE  FC  AH VMA  SA FLOW 49
# 1133 NAE  FC  AH VMA  SAFLOW STPT 8
# 1134 NAE  FC  AH VMA  CLG CMD 46
# 1135 NAE  FC  AH VMA  COM STPT 21
# 1136 NAE  FC  AH VMA  ACTCLG STPT 14
# 1137 NAE  FC  AH VMA  ACTHTG STPT 16
# 1138 NAE  FC  EFX VMA  ZN T 103
# 1139 NAE  FC  EFX VMA  EA FLOW 55
# 1140 NAE  FC  EFX VMA  EAFLOW STPT 10
# 1141 NAE  FC  AH VMA  WC ADJ 42
# 1142 NAE  FC  AH VMA  SA FLOW 49
# 1143 NAE  FC  AH VMA  SAFLOW STPT 8
# 1144 NAE  FC  AH VMA  CLG CMD 46
# 1145 NAE  FC  AH VMA  COM STPT 21
# 1146 NAE  FC  AH VMA  ACTCLG STPT 14
# 1147 NAE  FC  AH VMA  ACTHTG STPT 16
# 1148 NAE  FC  EFX VMA  ZN T 104
# 1149 NAE  FC  EFX VMA  EA FLOW 54
# 1150 NAE  FC  EFX VMA  EAFLOW STPT 9
# 1151 NAE  FC  AH SAV  ZN STPT 101
# 1152 NAE  FC  AH SAV  ACTCLG STPT 14
# 1153 NAE  FC  AH SAV  ACTHTG STPT 16
# 1154 NAE  FC  AH SAV  COM STPT 21
# 1155 NAE  FC  AH SAV  HTG DMD 38
# 1156 NAE  FC  AH SAV  CLG DMD 40
# 1157 NAE  FC  AH SAV  OCCCLG DB 25
# 1158 NAE  FC  AH SAV  OCCHTG DB 28
# 1159 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 1160 NAE  FC  AH SAV  EXHFLOW FEEDBACK 4
# 1161 NAE  FC  AH SAV  UNLOCK CODE 33
# 1162 NAE  FC  AH SAV  ZN STPT 101
# 1163 NAE  FC  AH SAV  ACTCLG STPT 14
# 1164 NAE  FC  AH SAV  ACTHTG STPT 16
# 1165 NAE  FC  AH SAV  COM STPT 21
# 1166 NAE  FC  AH SAV  HTG DMD 38
# 1167 NAE  FC  AH SAV  CLG DMD 40
# 1168 NAE  FC  AH SAV  OCCCLG DB 25
# 1169 NAE  FC  AH SAV  OCCHTG DB 28
# 1170 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 1171 NAE  FC  AH SAV  UNLOCK CODE 33
# 1172 NAE  FC  AH VMA  WC ADJ 42
# 1173 NAE  FC  AH VMA  SA FLOW 49
# 1174 NAE  FC  AH VMA  SAFLOW STPT 8
# 1175 NAE  FC  AH VMA  CLG CMD 46
# 1176 NAE  FC  AH VMA  COM STPT 21
# 1177 NAE  FC  AH VMA  ACTCLG STPT 14
# 1178 NAE  FC  AH VMA  ACTHTG STPT 16
# 1179 NAE  FC  EFX VMA  ZN T 103
# 1180 NAE  FC  EFX VMA  EA FLOW 55
# 1181 NAE  FC  EFX VMA  EAFLOW STPT 10
# 1182 NAE  FC  AH VMA  WC ADJ 42
# 1183 NAE  FC  AH VMA  SA FLOW 49
# 1184 NAE  FC  AH VMA  SAFLOW STPT 8
# 1185 NAE  FC  AH VMA  CLG CMD 46
# 1186 NAE  FC  AH VMA  COM STPT 21
# 1187 NAE  FC  AH VMA  ACTCLG STPT 14
# 1188 NAE  FC  AH VMA  ACTHTG STPT 16
# 1189 NAE  FC  AH VMA  WC ADJ 42
# 1190 NAE  FC  AH VMA  SA FLOW 49
# 1191 NAE  FC  AH VMA  SAFLOW STPT 8
# 1192 NAE  FC  AH VMA  CLG CMD 46
# 1193 NAE  FC  AH VMA  COM STPT 21
# 1194 NAE  FC  AH VMA  ACTCLG STPT 14
# 1195 NAE  FC  AH VMA  ACTHTG STPT 16
# 1196 NAE  FC  AH SAV  ZN STPT 101
# 1197 NAE  FC  AH SAV  ACTCLG STPT 14
# 1198 NAE  FC  AH SAV  ACTHTG STPT 16
# 1199 NAE  FC  AH SAV  COM STPT 21
# 1200 NAE  FC  AH SAV  HTG DMD 38
# 1201 NAE  FC  AH SAV  CLG DMD 40
# 1202 NAE  FC  AH SAV  OCCCLG DB 25
# 1203 NAE  FC  AH SAV  OCCHTG DB 28
# 1204 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 1205 NAE  FC  AH SAV  EXHFLOW FEEDBACK 4
# 1206 NAE  FC  AH SAV  UNLOCK CODE 33
# 1207 NAE  FC  AH VMA  WC ADJ 42
# 1208 NAE  FC  AH VMA  SA FLOW 49
# 1209 NAE  FC  AH VMA  SAFLOW STPT 8
# 1210 NAE  FC  AH VMA  CLG CMD 46
# 1211 NAE  FC  AH VMA  COM STPT 21
# 1212 NAE  FC  AH VMA  ACTCLG STPT 14
# 1213 NAE  FC  AH VMA  ACTHTG STPT 16
# 1214 NAE  FC  EFX VMA  ZN T 103
# 1215 NAE  FC  EFX VMA  EA FLOW 55
# 1216 NAE  FC  EFX VMA  EAFLOW STPT 10
# 1217 NAE  FC  EFX VMA  ZN T 103
# 1218 NAE  FC  EFX VMA  EA FLOW 55
# 1219 NAE  FC  EFX VMA  EAFLOW STPT 10
# 1220 NAE  FC  AH VMA  WC ADJ 42
# 1221 NAE  FC  AH VMA  SA FLOW 49
# 1222 NAE  FC  AH VMA  SAFLOW STPT 8
# 1223 NAE  FC  AH VMA  CLG CMD 46
# 1224 NAE  FC  AH VMA  COM STPT 21
# 1225 NAE  FC  AH VMA  ACTCLG STPT 14
# 1226 NAE  FC  AH VMA  ACTHTG STPT 16
# 1227 NAE  FC  AH SAV  ZN STPT 101
# 1228 NAE  FC  AH SAV  ACTCLG STPT 14
# 1229 NAE  FC  AH SAV  ACTHTG STPT 16
# 1230 NAE  FC  AH SAV  COM STPT 21
# 1231 NAE  FC  AH SAV  HTG DMD 38
# 1232 NAE  FC  AH SAV  CLG DMD 40
# 1233 NAE  FC  AH SAV  OCCCLG DB 25
# 1234 NAE  FC  AH SAV  OCCHTG DB 28
# 1235 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 1236 NAE  FC  AH SAV  UNLOCK CODE 33
# 1237 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 1238 NAE  FC  AH SAV  UNLOCK CODE 33
# 1239 NAE  FC  AH SAV  ZN STPT 101
# 1240 NAE  FC  AH SAV  ACTCLG STPT 14
# 1241 NAE  FC  AH SAV  ACTHTG STPT 16
# 1242 NAE  FC  AH SAV  COM STPT 21
# 1243 NAE  FC  AH SAV  HTG DMD 38
# 1244 NAE  FC  AH SAV  CLG DMD 40
# 1245 NAE  FC  AH SAV  OCCCLG DB 25
# 1246 NAE  FC  AH SAV  OCCHTG DB 28
# 1247 NAE  FC  AH SAV  UNLOCK CODE 33
# 1248 NAE  FC  AH VMA  WC ADJ 42
# 1249 NAE  FC  AH VMA  SA FLOW 49
# 1250 NAE  FC  AH VMA  SAFLOW STPT 8
# 1251 NAE  FC  AH VMA  CLG CMD 46
# 1252 NAE  FC  AH VMA  COM STPT 21
# 1253 NAE  FC  AH VMA  ACTCLG STPT 14
# 1254 NAE  FC  AH VMA  ACTHTG STPT 16
# 1255 NAE  FC  AH FEC  COM STPT 21
# 1256 NAE  FC  AH FEC  ACTCLG STPT 14
# 1257 NAE  FC  AH FEC  ACTHTG STPT 16
# 1258 NAE  FC  AH FEC  CLG CMD 46
# 1259 NAE  FC  AH FEC  SAFLOW STPT 8
# 1260 NAE  FC  EFX VMA  ZN T 103
# 1261 NAE  FC  EFX VMA  EA FLOW 55
# 1262 NAE  FC  EFX VMA  EAFLOW STPT 10
# 1263 NAE  FC  AH VMA  WC ADJ 42
# 1264 NAE  FC  AH VMA  SA FLOW 49
# 1265 NAE  FC  AH VMA  SAFLOW STPT 8
# 1266 NAE  FC  AH VMA  CLG CMD 46
# 1267 NAE  FC  AH VMA  COM STPT 21
# 1268 NAE  FC  AH VMA  ACTCLG STPT 14
# 1269 NAE  FC  AH VMA  ACTHTG STPT 16
# 1270 NAE  FC  AH FEC  ZN T 104
# 1271 NAE  Programming AHU NAE HIZNT 273
# 1272 NAE  Programming AHU NAE LOZNT 273
# 1273 NAE  Programming AHU NAE AVGZNT 273
# 1274 NAE  Programming AHU NAE HIZNT 273
# 1275 NAE  Programming AHU NAE LOZNT 273
# 1276 NAE  Programming AHU NAE AVGZNT 273
# 1277 NAE  FC  EFX EAV  EXHFLOW FEEDBACK 5
# 1278 NAE  FC  EF  EAV  EXHFLOW FEEDBACK 6
# 1279 NAE  FC  EF  EAV  EXHFLOW FEEDBACK 6
# 1280 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 1281 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 1282 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 1283 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 1284 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 1285 NAE  FC  AH SAV  AV 275
# 1286 NAE  FC  AH SAV  AV 275
# 1287 NAE  FC  AH SAV  AV  269
# 1288 NAE  FC  AH SAV  AV  269
# 1289 NAE  Programming Zone Load Shed BONNER MTWT SP Load Shed 267
# 1290 NAE  Programming Zone Load Shed BONNER CHWDP SP Load Shed 268
# 1291 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 1292 NAE  FC  AH FEC  EMER PB 82
# 1293 NAE  FC  AH FEC  OCC SENS 85
# 1294 NAE  FC  AH VMA  OCC SEN 85
# 1295 NAE  FC  AH FEC  EMER PB 82
# 1296 NAE  FC  AH FEC  OCC SENS 85
# 1297 NAE  FC  AH FEC  EMER PB 82
# 1298 NAE  FC  AH FEC  OCC SENS 85
# 1299 NAE  FC  AH FEC  EMER PB 82
# 1300 NAE  FC  AH FEC  OCC SENS 84
# 1301 NAE  FC  AH VMA  OCC SEN 86
# 1302 NAE  FC  AH FEC  EMER PB 82
# 1303 NAE  FC  AH FEC  OCC SENS 84
# 1304 NAE  FC  AH VMA  OCC SEN 86
# 1305 NAE  FC  AH VMA  OCC SEN 86
# 1306 NAE  FC  AH VMA  OCC SEN 86
# 1307 NAE  FC  AH VMA  OCC SEN 86
# 1308 NAE  FC  AH VMA  OCC SEN 86
# 1309 NAE  FC  AH VMA  OCC SEN 86
# 1310 NAE  FC  AH VMA  OCC SEN 86
# 1311 NAE  FC  AH VMA  OCC SEN 86
# 1312 NAE  FC  AH FEC  EMER PB 82
# 1313 NAE  FC  AH FEC  OCC SENS 84
# 1314 NAE  FC  AH VMA  OCC SEN 86
# 1315 NAE  FC  AH FEC  ENVIRO 81
# 1316 NAE  FC  AH FEC  ENVIRO 81
# 1317 NAE  FC  AH FEC  ENVIRO 81
# 1318 NAE  FC  AH FEC  ENVIRO 81
# 1319 NAE  FC  AH FEC  ENVIRO 81
# 1320 NAE  FC  AH FEC  ENVIRO 81
# 1321 NAE  FC  AH SAV  OCC CMD 88
# 1322 NAE  FC  AH SAV  OCC STS 91
# 1323 NAE  FC  AH SAV  OCC CMD 88
# 1324 NAE  FC  AH SAV  OCC STS 91
# 1325 NAE  FC  AH SAV  OCC CMD 88
# 1326 NAE  FC  AH SAV  OCC STS 91
# 1327 NAE  FC  AH SAV  OCC CMD 88
# 1328 NAE  FC  AH SAV  OCC STS 91
# 1329 NAE  FC  AH SAV  OCC CMD 88
# 1330 NAE  FC  AH SAV  OCC STS 91
# 1331 NAE  FC  AH SAV  OCC CMD 88
# 1332 NAE  FC  AH SAV  OCC STS 91
# 1333 NAE  FC  AH SAV  OCC CMD 88
# 1334 NAE  FC  AH SAV  OCC STS 91
# 1335 NAE  FC  AH SAV  OCC CMD 88
# 1336 NAE  FC  AH SAV  OCC STS 91
# 1337 NAE  FC  AH SAV  OCC CMD 88
# 1338 NAE  FC  AH SAV  OCC STS 91
# 1339 NAE  FC  AH SAV  OCC CMD 88
# 1340 NAE  FC  AH SAV  OCC STS 91
# 1341 NAE  FC  AH SAV  OCC CMD 88
# 1342 NAE  FC  AH SAV  OCC STS 91
# 1343 NAE  FC  AH SAV  OCC CMD 88
# 1344 NAE  FC  AH SAV  OCC STS 91
# 1345 NAE  FC  AH SAV  OCC CMD 88
# 1346 NAE  FC  AH SAV  OCC STS 91
# 1347 NAE  FC  AH SAV  OCC CMD 88
# 1348 NAE  FC  AH SAV  OCC STS 91
# 1349 NAE  FC  AH SAV  OCC CMD 88
# 1350 NAE  FC  AH SAV  OCC STS 91
# 1351 NAE  FC  AH SAV  OCC CMD 88
# 1352 NAE  FC  AH SAV  OCC STS 91
# 1353 NAE  FC  AH SAV  EMER PB 83
# 1354 NAE  FC  AH SAV  OCC CMD 88
# 1355 NAE  FC  AH SAV  OCC STS 91
# 1356 NAE  FC  AH SAV  OCC CMD 88
# 1357 NAE  FC  AH SAV  OCC STS 91
# 1358 NAE  FC  AH SAV  EMER PB 83
# 1359 NAE  FC  AH SAV  OCC CMD 88
# 1360 NAE  FC  AH SAV  OCC STS 91
# 1361 NAE  FC  AH SAV  EMER PB 83
# 1362 NAE  FC  AH SAV  OCC CMD 88
# 1363 NAE  FC  AH SAV  OCC STS 91
# 1364 NAE  FC  AH SAV  EMER PB 83
# 1365 NAE  FC  AH SAV  OCC CMD 88
# 1366 NAE  FC  AH SAV  OCC STS 91
# 1367 NAE  FC  AH SAV  OCC CMD 88
# 1368 NAE  FC  AH SAV  OCC STS 91
# 1369 NAE  FC  AH SAV  OCC CMD 88
# 1370 NAE  FC  AH SAV  OCC STS 91
# 1371 NAE  FC  AH SAV  OCC CMD 88
# 1372 NAE  FC  AH SAV  OCC STS 91
# 1373 NAE  FC  AH SAV  OCC CMD 88
# 1374 NAE  FC  AH SAV  OCC STS 91
# 1375 NAE  FC  AH SAV  EMER PB 83
# 1376 NAE  FC  AH SAV  OCC CMD 88
# 1377 NAE  FC  AH SAV  OCC STS 91
# 1378 NAE  Programming Zone Load Shed BONNER st Floor Lab Load Shed 140
# 1379 NAE  Programming Zone Load Shed BONNER Lab Load Shed Command 141
# 1380 NAE  Programming Zone Load Shed BONNER MTW T Load Shed 142
# 1381 NAE  Programming Zone Load Shed BONNER CHW DP Load Shed 143
# 1382 NAE  FC  AH SAV  BV  139
# 1383 NAE  FC  AH FEC  FUME ALM 71
# 1384 NAE  FC  AH FEC  OCC CMD 74
# 1385 NAE  FC  AH FEC  OCC STS 79
# 1386 NAE  FC  AH VMA  OCC CMD 74
# 1387 NAE  FC  AH VMA  OCC STS 76
# 1388 NAE  FC  EF  VMA  OCC STS 79
# 1389 NAE  FC  AH FEC  FUME ALM 71
# 1390 NAE  FC  AH FEC  OCC CMD 74
# 1391 NAE  FC  AH FEC  OCC STS 79
# 1392 NAE  FC  AH FEC  FUME ALM 71
# 1393 NAE  FC  AH FEC  OCC CMD 74
# 1394 NAE  FC  AH FEC  OCC STS 79
# 1395 NAE  FC  AH FEC  OCC CMD 75
# 1396 NAE  FC  AH FEC  OCC STS 78
# 1397 NAE  FC  AH FEC  FUME ALM 71
# 1398 NAE  FC  AH VMA  OCC CMD 75
# 1399 NAE  FC  AH VMA  OCC STS 76
# 1400 NAE  FC  EF  VMA  OCC STS 78
# 1401 NAE  FC  AH FEC  OCC CMD 75
# 1402 NAE  FC  AH FEC  OCC STS 78
# 1403 NAE  FC  AH FEC  FUME ALM 71
# 1404 NAE  FC  AH VMA  OCC CMD 75
# 1405 NAE  FC  AH VMA  OCC STS 76
# 1406 NAE  FC  EFX VMA  OCC STS 78
# 1407 NAE  FC  AH VMA  OCC CMD 75
# 1408 NAE  FC  AH VMA  OCC STS 76
# 1409 NAE  FC  EFX VMA  OCC STS 78
# 1410 NAE  FC  AH VMA  OCC CMD 75
# 1411 NAE  FC  AH VMA  OCC STS 76
# 1412 NAE  FC  EFX VMA  OCC STS 78
# 1413 NAE  FC  AH VMA  OCC CMD 75
# 1414 NAE  FC  AH VMA  OCC STS 76
# 1415 NAE  FC  AH VMA  OCC CMD 75
# 1416 NAE  FC  AH VMA  OCC STS 76
# 1417 NAE  FC  AH VMA  OCC CMD 75
# 1418 NAE  FC  AH VMA  OCC STS 76
# 1419 NAE  FC  EFX VMA  OCC STS 78
# 1420 NAE  FC  EFX VMA  OCC STS 78
# 1421 NAE  FC  AH VMA  OCC CMD 75
# 1422 NAE  FC  AH VMA  OCC STS 76
# 1423 NAE  FC  AH VMA  OCC CMD 75
# 1424 NAE  FC  AH VMA  OCC STS 76
# 1425 NAE  FC  AH FEC  OCC CMD 75
# 1426 NAE  FC  AH FEC  OCC STS 78
# 1427 NAE  FC  AH FEC  FUME ALM 71
# 1428 NAE  FC  EFX VMA  OCC STS 78
# 1429 NAE  FC  AH VMA  OCC CMD 75
# 1430 NAE  FC  AH VMA  OCC STS 76
# 1431 NAE  Programming Zone Load Shed BONNER stFlr Office Load Shed 70
# 1432 NAE  Programming Zone Load Shed BONNER Office Load Shed Command 70
# 1433 NAE  FC  AH VMA  ZN T 98
# 1434 NAE  FC  AH VMA  SA T 48
# 1435 NAE  FC  EFX VMA  EA VP 53
# 1436 NAE  FC  AH SAV  ZN T 98
# 1437 NAE  FC  AH SAV  ZN T 98
# 1438 NAE  FC  AH FEC  ZN T 98
# 1439 NAE  FC  AH FEC  EA FLOW 58
# 1440 NAE  FC  AH FEC  FUME FLOW 56
# 1441 NAE  FC  AH FEC  FUME SASH 93
# 1442 NAE  FC  AH SAV  ZN T 98
# 1443 NAE  FC  AH SAV  ZN T 98
# ...
# 2738 NAE  FC  AH VMA  ZN T 98
# 2739 NAE  FC  AH VMA  SA T 48
# 2740 NAE  FC  EFX VMA  EA VP 53
# 2741 NAE  FC  EFX VMA  DPR CMD 66
# 2742 NAE  FC  AH VMA  DPR CMD 66
# 2743 NAE  FC  AH VMA  HTGVLV CMD 59
# 2744 NAE  FC  EFX VMA  DPR CMD 66
# 2745 NAE  FC  AH VMA  DPR CMD 66
# 2746 NAE  FC  AH VMA  HTGVLV CMD 59
# 2747 NAE  FC  AH SAV  HTGVLV CMD 63
# 2748 NAE  FC  AHX SAV  HTGVLV CMD 63
# 2749 NAE  FC  AHX VMA  DPR CMD 66
# 2750 NAE  FC  AHX VMA  HTGVLV CMD 59
# 2751 NAE  FC  EFX VMA  DPR CMD 66
# 2752 NAE  FC  AH SAV  HTGVLV CMD 63
# 2753 NAE  FC  AH VMA  DPR CMD 66
# 2754 NAE  FC  AH VMA  HTGVLV CMD 59
# 2755 NAE  FC  EFX VMA  DPR CMD 66
# 2756 NAE  FC  AH VMA  DPR CMD 66
# 2757 NAE  FC  AH VMA  HTGVLV CMD 59
# 2758 NAE  FC  EFX VMA  DPR CMD 66
# 2759 NAE  FC  AH SAV  HTGVLV CMD 63
# 2760 NAE  FC  AH SAV  HTGVLV CMD 63
# 2761 NAE  FC  AH SAV  HTGVLV CMD 63
# 2762 NAE  FC  AH FEC  HTGVLV CMD 59
# 2763 NAE  FC  AH VMA  DPR CMD 66
# 2764 NAE  FC  AH VMA  HTGVLV CMD 59
# 2765 NAE  FC  EFX VMA  DPR CMD 66
# 2766 NAE  FC  AH VMA  DPR CMD 66
# 2767 NAE  FC  AH VMA  HTGVLV CMD 59
# 2768 NAE  FC  EFX VMA  DPR CMD 66
# 2769 NAE  FC  AH VMA  DPR CMD 66
# 2770 NAE  FC  AH VMA  HTGVLV CMD 59
# 2771 NAE  FC  EFX VMA  DPR CMD 66
# 2772 NAE  FC  AH SAV  HTGVLV CMD 63
# 2773 NAE  FC  AH SAV  HTGVLV CMD 63
# 2774 NAE  FC  AH SAV  HTGVLV CMD 63
# 2775 NAE  FC  AH VMA  DPR CMD 66
# 2776 NAE  FC  AH VMA  HTGVLV CMD 59
# 2777 NAE  FC  EFX VMA  DPR CMD 66
# 2778 NAE  FC  EFX VMA  ZN T 103
# 2779 NAE  FC  EFX VMA  EA FLOW 55
# 2780 NAE  FC  EFX VMA  EAFLOW STPT 10
# 2781 NAE  FC  AH VMA  WC ADJ 42
# 2782 NAE  FC  AH VMA  SA FLOW 49
# 2783 NAE  FC  AH VMA  SAFLOW STPT 8
# 2784 NAE  FC  AH VMA  CLG CMD 44
# 2785 NAE  FC  AH VMA  COM STPT 19
# 2786 NAE  FC  AH VMA  ACTCLG STPT 14
# 2787 NAE  FC  AH VMA  ACTHTG STPT 16
# 2788 NAE  FC  EFX VMA  ZN T 103
# 2789 NAE  FC  EFX VMA  EA FLOW 55
# 2790 NAE  FC  EFX VMA  EAFLOW STPT 10
# 2791 NAE  FC  AH VMA  WC ADJ 42
# 2792 NAE  FC  AH VMA  SA FLOW 49
# 2793 NAE  FC  AH VMA  SAFLOW STPT 8
# 2794 NAE  FC  AH VMA  CLG CMD 44
# 2795 NAE  FC  AH VMA  COM STPT 19
# 2796 NAE  FC  AH VMA  ACTCLG STPT 14
# 2797 NAE  FC  AH VMA  ACTHTG STPT 16
# 2798 NAE  FC  AH SAV  ZN STPT 101
# 2799 NAE  FC  AH SAV  ACTCLG STPT 14
# 2800 NAE  FC  AH SAV  ACTHTG STPT 16
# 2801 NAE  FC  AH SAV  COM STPT 23
# 2802 NAE  FC  AH SAV  HTG DMD 38
# 2803 NAE  FC  AH SAV  CLG DMD 40
# 2804 NAE  FC  AH SAV  OCCCLG DB 25
# 2805 NAE  FC  AH SAV  OCCHTG DB 28
# 2806 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 2807 NAE  FC  AH SAV  EXHFLOW FEEDBACK 4
# 2808 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 2809 NAE  FC  AH SAV  UNLOCK CODE 31
# 2810 NAE  FC  AHX SAV  ZN STPT 102
# 2811 NAE  FC  AHX SAV  ACTCLG STPT 11
# 2812 NAE  FC  AHX SAV  ACTHTG STPT 12
# 2813 NAE  FC  AHX SAV  COM STPT 23
# 2814 NAE  FC  AHX SAV  HTG DMD 35
# 2815 NAE  FC  AHX SAV  CLG DMD 36
# 2816 NAE  FC  AHX SAV  OCCCLG DB 26
# 2817 NAE  FC  AHX SAV  OCCHTG DB 29
# 2818 NAE  FC  AHX SAV  SUPFLOW FEEDBACK 3
# 2819 NAE  FC  AHX SAV  UNLOCK CODE 34
# 2820 NAE  FC  AHX VMA  WC ADJ 42
# 2821 NAE  FC  AHX VMA  SA FLOW 49
# 2822 NAE  FC  AHX VMA  SAFLOW STPT 8
# 2823 NAE  FC  AHX VMA  CLG CMD 44
# 2824 NAE  FC  AHX VMA  COM STPT 19
# 2825 NAE  FC  AHX VMA  ACTCLG STPT 14
# 2826 NAE  FC  AHX VMA  ACTHTG STPT 16
# 2827 NAE  FC  EFX VMA  ZN T 103
# 2828 NAE  FC  EFX VMA  EA FLOW 55
# 2829 NAE  FC  EFX VMA  EAFLOW STPT 10
# 2830 NAE  FC  AH SAV  ZN STPT 101
# 2831 NAE  FC  AH SAV  ACTCLG STPT 14
# 2832 NAE  FC  AH SAV  ACTHTG STPT 16
# 2833 NAE  FC  AH SAV  COM STPT 23
# 2834 NAE  FC  AH SAV  HTG DMD 38
# 2835 NAE  FC  AH SAV  CLG DMD 40
# 2836 NAE  FC  AH SAV  OCCCLG DB 25
# 2837 NAE  FC  AH SAV  OCCHTG DB 28
# 2838 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 2839 NAE  FC  AH SAV  UNLOCK CODE 31
# 2840 NAE  FC  AH VMA  WC ADJ 42
# 2841 NAE  FC  AH VMA  SA FLOW 49
# 2842 NAE  FC  AH VMA  SAFLOW STPT 8
# 2843 NAE  FC  AH VMA  CLG CMD 44
# 2844 NAE  FC  AH VMA  COM STPT 19
# 2845 NAE  FC  AH VMA  ACTCLG STPT 14
# 2846 NAE  FC  AH VMA  ACTHTG STPT 16
# 2847 NAE  FC  EFX VMA  ZN T 103
# 2848 NAE  FC  EFX VMA  EA FLOW 55
# 2849 NAE  FC  EFX VMA  EAFLOW STPT 10
# 2850 NAE  FC  AH VMA  WC ADJ 42
# 2851 NAE  FC  AH VMA  SA FLOW 49
# 2852 NAE  FC  AH VMA  SAFLOW STPT 8
# 2853 NAE  FC  AH VMA  CLG CMD 44
# 2854 NAE  FC  AH VMA  COM STPT 19
# 2855 NAE  FC  AH VMA  ACTCLG STPT 14
# 2856 NAE  FC  AH VMA  ACTHTG STPT 16
# 2857 NAE  FC  EFX VMA  ZN T 105
# 2858 NAE  FC  EFX VMA  EA FLOW 54
# 2859 NAE  FC  EFX VMA  EAFLOW STPT 9
# 2860 NAE  FC  AH SAV  ZN STPT 101
# 2861 NAE  FC  AH SAV  ACTCLG STPT 14
# 2862 NAE  FC  AH SAV  ACTHTG STPT 16
# 2863 NAE  FC  AH SAV  COM STPT 23
# 2864 NAE  FC  AH SAV  HTG DMD 38
# 2865 NAE  FC  AH SAV  CLG DMD 40
# 2866 NAE  FC  AH SAV  OCCCLG DB 25
# 2867 NAE  FC  AH SAV  OCCHTG DB 28
# 2868 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 2869 NAE  FC  AH SAV  EXHFLOW FEEDBACK 4
# 2870 NAE  FC  AH SAV  UNLOCK CODE 31
# 2871 NAE  FC  AH EAV  UNLOCK CODE 31
# 2872 NAE  FC  AH SAV  ZN STPT 101
# 2873 NAE  FC  AH SAV  ACTCLG STPT 14
# 2874 NAE  FC  AH SAV  ACTHTG STPT 16
# 2875 NAE  FC  AH SAV  COM STPT 23
# 2876 NAE  FC  AH SAV  HTG DMD 38
# 2877 NAE  FC  AH SAV  CLG DMD 40
# 2878 NAE  FC  AH SAV  OCCCLG DB 25
# 2879 NAE  FC  AH SAV  OCCHTG DB 28
# 2880 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 2881 NAE  FC  AH SAV  EXHFLOW FEEDBACK 4
# 2882 NAE  FC  AH SAV  UNLOCK CODE 31
# 2883 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 2884 NAE  FC  AH SAV  UNLOCK CODE 31
# 2885 NAE  FC  AH SAV  ZN STPT 101
# 2886 NAE  FC  AH SAV  ACTCLG STPT 14
# 2887 NAE  FC  AH SAV  ACTHTG STPT 16
# 2888 NAE  FC  AH SAV  COM STPT 23
# 2889 NAE  FC  AH SAV  HTG DMD 38
# 2890 NAE  FC  AH SAV  CLG DMD 40
# 2891 NAE  FC  AH SAV  OCCCLG DB 25
# 2892 NAE  FC  AH SAV  OCCHTG DB 28
# 2893 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 2894 NAE  FC  AH SAV  EXHFLOW FEEDBACK 4
# 2895 NAE  FC  AH SAV  UNLOCK CODE 31
# 2896 NAE  FC  AH FEC  WC ADJ 42
# 2897 NAE  FC  AH FEC  COM STPT 19
# 2898 NAE  FC  AH FEC  ACTCLG STPT 14
# 2899 NAE  FC  AH FEC  ACTHTG STPT 16
# 2900 NAE  FC  AH FEC  CLG CMD 44
# 2901 NAE  FC  AH FEC  SAFLOW STPT 8
# 2902 NAE  FC  AH VMA  WC ADJ 42
# 2903 NAE  FC  AH VMA  SA FLOW 49
# 2904 NAE  FC  AH VMA  SAFLOW STPT 8
# 2905 NAE  FC  AH VMA  CLG CMD 44
# 2906 NAE  FC  AH VMA  COM STPT 19
# 2907 NAE  FC  AH VMA  ACTCLG STPT 14
# 2908 NAE  FC  AH VMA  ACTHTG STPT 16
# 2909 NAE  FC  EFX VMA  ZN T 103
# 2910 NAE  FC  EFX VMA  EA FLOW 55
# 2911 NAE  FC  EFX VMA  EAFLOW STPT 10
# 2912 NAE  FC  AH VMA  WC ADJ 42
# 2913 NAE  FC  AH VMA  SA FLOW 49
# 2914 NAE  FC  AH VMA  SAFLOW STPT 8
# 2915 NAE  FC  AH VMA  CLG CMD 44
# 2916 NAE  FC  AH VMA  COM STPT 19
# 2917 NAE  FC  AH VMA  ACTCLG STPT 14
# 2918 NAE  FC  AH VMA  ACTHTG STPT 16
# 2919 NAE  FC  EFX VMA  ZN T 103
# 2920 NAE  FC  EFX VMA  EA FLOW 55
# 2921 NAE  FC  EFX VMA  EAFLOW STPT 10
# 2922 NAE  FC  AH VMA  WC ADJ 42
# 2923 NAE  FC  AH VMA  SA FLOW 49
# 2924 NAE  FC  AH VMA  SAFLOW STPT 8
# 2925 NAE  FC  AH VMA  CLG CMD 44
# 2926 NAE  FC  AH VMA  COM STPT 19
# 2927 NAE  FC  AH VMA  ACTCLG STPT 14
# 2928 NAE  FC  AH VMA  ACTHTG STPT 16
# 2929 NAE  FC  EFX VMA  ZN T 103
# 2930 NAE  FC  EFX VMA  EA FLOW 55
# 2931 NAE  FC  EFX VMA  EAFLOW STPT 10
# 2932 NAE  FC  AH SAV  ZN STPT 101
# 2933 NAE  FC  AH SAV  ACTCLG STPT 14
# 2934 NAE  FC  AH SAV  ACTHTG STPT 16
# 2935 NAE  FC  AH SAV  COM STPT 23
# 2936 NAE  FC  AH SAV  HTG DMD 38
# 2937 NAE  FC  AH SAV  CLG DMD 40
# 2938 NAE  FC  AH SAV  OCCCLG DB 25
# 2939 NAE  FC  AH SAV  OCCHTG DB 28
# 2940 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 2941 NAE  FC  AH SAV  EXHFLOW FEEDBACK 4
# 2942 NAE  FC  AH SAV  UNLOCK CODE 31
# 2943 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 2944 NAE  FC  AH SAV  UNLOCK CODE 31
# 2945 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 2946 NAE  FC  AH SAV  UNLOCK CODE 31
# 2947 NAE  FC  EFX EAV  UNLOCK CODE 31
# 2948 NAE  FC  AH SAV  ZN STPT 101
# 2949 NAE  FC  AH SAV  ACTCLG STPT 14
# 2950 NAE  FC  AH SAV  ACTHTG STPT 16
# 2951 NAE  FC  AH SAV  COM STPT 23
# 2952 NAE  FC  AH SAV  HTG DMD 38
# 2953 NAE  FC  AH SAV  CLG DMD 40
# 2954 NAE  FC  AH SAV  OCCCLG DB 25
# 2955 NAE  FC  AH SAV  OCCHTG DB 28
# 2956 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 2957 NAE  FC  AH SAV  EXHFLOW FEEDBACK 4
# 2958 NAE  FC  AH SAV  UNLOCK CODE 31
# 2959 NAE  FC  AH SAV  ZN STPT 101
# 2960 NAE  FC  AH SAV  ACTCLG STPT 14
# 2961 NAE  FC  AH SAV  ACTHTG STPT 16
# 2962 NAE  FC  AH SAV  COM STPT 23
# 2963 NAE  FC  AH SAV  HTG DMD 38
# 2964 NAE  FC  AH SAV  CLG DMD 40
# 2965 NAE  FC  AH SAV  OCCCLG DB 25
# 2966 NAE  FC  AH SAV  OCCHTG DB 28
# 2967 NAE  FC  AH SAV  SUPFLOW FEEDBACK 2
# 2968 NAE  FC  AH SAV  EXHFLOW FEEDBACK 4
# 2969 NAE  FC  AH SAV  UNLOCK CODE 31
# 2970 NAE  FC  AH VMA  WC ADJ 42
# 2971 NAE  FC  AH VMA  SA FLOW 49
# 2972 NAE  FC  AH VMA  SAFLOW STPT 8
# 2973 NAE  FC  AH VMA  CLG CMD 44
# 2974 NAE  FC  AH VMA  COM STPT 19
# 2975 NAE  FC  AH VMA  ACTCLG STPT 14
# 2976 NAE  FC  AH VMA  ACTHTG STPT 16
# 2977 NAE  FC  EFX VMA  ZN T 103
# 2978 NAE  FC  EFX VMA  EA FLOW 55
# 2979 NAE  FC  EFX VMA  EAFLOW STPT 10
# 2980 NAE  Programming AHU NAE HIZNT 273
# 2981 NAE  Programming AHU NAE LOZNT 273
# 2982 NAE  Programming AHU NAE AVGZNT 273
# 2983 NAE  Programming AHU NAE HIZNT 273
# 2984 NAE  Programming AHU NAE LOZNT 273
# 2985 NAE  Programming AHU NAE AVGZNT 273
# 2986 NAE  FC  AH EAV  EXHFLOW FEEDBACK 6
# 2987 NAE  FC  EFX EAV  EXHFLOW FEEDBACK 6
# 2988 NAE  FC  AH SAV  UNLOCK CODE 31
# 2989 NAE  FC  VFD  FREQ 283
# 2990 NAE  FC  VFD  VFD AMP 282
# 2991 NAE  FC  VFD  VOLTS 284
# 2992 NAE  FC  VFD  PWR KW 280
# 2993 NAE  FC  VFD  RUN HRS 278
# 2994 NAE  FC  VFD  KW HRS 279
# 2995 NAE  FC  VFD  MW HRS 277
# 2996 NAE  FC  VFD  DRIVE T 281
# 2997 NAE  FC  VFD  RPM 276
# 2998 NAE  FC  VFD  FREQ 283
# 2999 NAE  FC  VFD  VFD AMP 282
# 3000 NAE  FC  VFD  VOLTS 284
# 3001 NAE  FC  VFD  PWR KW 280
# 3002 NAE  FC  VFD  RUN HRS 278
# 3003 NAE  FC  VFD  KW HRS 279
# 3004 NAE  FC  VFD  MW HRS 277
# 3005 NAE  FC  VFD  DRIVE T 281
# 3006 NAE  FC  VFD  RPM 276
# 3007 NAE  FC  VFD  FREQ 283
# 3008 NAE  FC  VFD  VFD AMP 282
# 3009 NAE  FC  VFD  VOLTS 284
# 3010 NAE  FC  VFD  PWR KW 280
# 3011 NAE  FC  VFD  RUN HRS 278
# 3012 NAE  FC  VFD  KW HRS 279
# 3013 NAE  FC  VFD  MW HRS 277
# 3014 NAE  FC  VFD  DRIVE T 281
# 3015 NAE  FC  VFD  RPM 276
# 3016 NAE  FC  VFD  FREQ 283
# 3017 NAE  FC  VFD  VFD AMP 282
# 3018 NAE  FC  VFD  VOLTS 284
# 3019 NAE  FC  VFD  PWR KW 280
# 3020 NAE  FC  VFD  RUN HRS 278
# 3021 NAE  FC  VFD  KW HRS 279
# 3022 NAE  FC  VFD  MW HRS 277
# 3023 NAE  FC  VFD  DRIVE T 281
# 3024 NAE  FC  VFD  RPM 276
# 3025 NAE  FC  VFD  FREQ 283
# 3026 NAE  FC  VFD  VFD AMP 282
# 3027 NAE  FC  VFD  VOLTS 284
# 3028 NAE  FC  VFD  PWR KW 280
# 3029 NAE  FC  VFD  RUN HRS 278
# 3030 NAE  FC  VFD  KW HRS 279
# 3031 NAE  FC  VFD  MW HRS 277
# 3032 NAE  FC  VFD  DRIVE T 281
# 3033 NAE  FC  VFD  RPM 276
# 3034 NAE  FC  VFD  FREQ 283
# 3035 NAE  FC  VFD  VFD AMP 282
# 3036 NAE  FC  VFD  VOLTS 284
# 3037 NAE  FC  VFD  PWR KW 280
# 3038 NAE  FC  VFD  RUN HRS 278
# 3039 NAE  FC  VFD  KW HRS 279
# 3040 NAE  FC  VFD  MW HRS 277
# 3041 NAE  FC  VFD  DRIVE T 281
# 3042 NAE  FC  VFD  RPM 276
# 3043 NAE  FC  VFD  FREQ 283
# 3044 NAE  FC  VFD  VFD AMP 282
# 3045 NAE  FC  VFD  VOLTS 284
# 3046 NAE  FC  VFD  PWR KW 280
# 3047 NAE  FC  VFD  RUN HRS 278
# 3048 NAE  FC  VFD  KW HRS 279
# 3049 NAE  FC  VFD  MW HRS 277
# 3050 NAE  FC  VFD  DRIVE T 281
# 3051 NAE  FC  VFD  RPM 276
# 3052 NAE  FC  VFD  FREQ 283
# 3053 NAE  FC  VFD  VFD AMP 282
# 3054 NAE  FC  VFD  VOLTS 284
# 3055 NAE  FC  VFD  PWR KW 280
# 3056 NAE  FC  VFD  RUN HRS 278
# 3057 NAE  FC  VFD  KW HRS 279
# 3058 NAE  FC  VFD  MW HRS 277
# 3059 NAE  FC  VFD  DRIVE T 281
# 3060 NAE  FC  VFD  RPM 276
# 3061 NAE  FC  VFD  FREQ 283
# 3062 NAE  FC  VFD  VFD AMP 282
# 3063 NAE  FC  VFD  VOLTS 284
# 3064 NAE  FC  VFD  PWR KW 280
# 3065 NAE  FC  VFD  RUN HRS 278
# 3066 NAE  FC  VFD  KW HRS 279
# 3067 NAE  FC  VFD  MW HRS 277
# 3068 NAE  FC  VFD  DRIVE T 281
# 3069 NAE  FC  VFD  RPM 276
# 3070 NAE  FC  VFD  FREQ 283
# 3071 NAE  FC  VFD  VFD AMP 282
# 3072 NAE  FC  VFD  VOLTS 284
# 3073 NAE  FC  VFD  PWR KW 280
# 3074 NAE  FC  VFD  RUN HRS 278
# 3075 NAE  FC  VFD  KW HRS 279
# 3076 NAE  FC  VFD  MW HRS 277
# 3077 NAE  FC  VFD  DRIVE T 281
# 3078 NAE  FC  VFD  RPM 276
# 3079 NAE  FC  AH VMA  OCC SEN 86
# 3080 NAE  FC  AH VMA  OCC SEN 86
# 3081 NAE  FC  AHX VMA  OCC SEN 86
# 3082 NAE  FC  AH VMA  OCC SEN 86
# 3083 NAE  FC  AH VMA  OCC SEN 86
# 3084 NAE  FC  AH FEC  EMER PB 82
# 3085 NAE  FC  AH FEC  OCC SENS 84
# 3086 NAE  FC  AH VMA  OCC SEN 86
# 3087 NAE  FC  AH VMA  OCC SEN 86
# 3088 NAE  FC  AH VMA  OCC SEN 86
# 3089 NAE  FC  AH VMA  OCC SEN 86
# 3090 NAE  FC  AH FEC  ENVIRO 81
# 3091 NAE  FC  AH SAV  OCC CMD 88
# 3092 NAE  FC  AH SAV  OCC STS 91
# 3093 NAE  FC  AH SAV  OCC CMD 88
# 3094 NAE  FC  AH SAV  OCC STS 91
# 3095 NAE  FC  AHX SAV  OCC CMD 89
# 3096 NAE  FC  AHX SAV  OCC STS 92
# 3097 NAE  FC  AH SAV  OCC CMD 88
# 3098 NAE  FC  AH SAV  OCC STS 91
# 3099 NAE  FC  AH SAV  OCC CMD 88
# 3100 NAE  FC  AH SAV  OCC STS 91
# 3101 NAE  FC  AH SAV  OCC CMD 88
# 3102 NAE  FC  AH SAV  OCC STS 91
# 3103 NAE  FC  AH SAV  EMER PB 83
# 3104 NAE  FC  AH SAV  OCC CMD 88
# 3105 NAE  FC  AH SAV  OCC STS 91
# 3106 NAE  FC  AH SAV  EMER PB 83
# 3107 NAE  FC  AH SAV  OCC CMD 88
# 3108 NAE  FC  AH SAV  OCC STS 91
# 3109 NAE  FC  AH SAV  OCC CMD 88
# 3110 NAE  FC  AH SAV  OCC STS 91
# 3111 NAE  FC  AH SAV  EMER PB 83
# 3112 NAE  FC  AH SAV  OCC CMD 88
# 3113 NAE  FC  AH SAV  OCC STS 91
# 3114 NAE  FC  AH SAV  EMER PB 83
# 3115 NAE  FC  AH SAV  OCC CMD 88
# 3116 NAE  FC  AH SAV  OCC STS 91
# 3117 NAE  FC  AH SAV  EMER PB 83
# 3118 NAE  FC  AH SAV  OCC CMD 88
# 3119 NAE  FC  AH SAV  OCC STS 91
# 3120 NAE  FC  AH SAV  OCC CMD 88
# 3121 NAE  FC  AH SAV  OCC STS 91
# 3122 NAE  FC  VFD  RUN ENB 132
# 3123 NAE  FC  VFD  VFD STS 135
# 3124 NAE  FC  VFD  HAND AUTO 134
# 3125 NAE  FC  VFD  FLT STS 136
# 3126 NAE  FC  VFD  ALARM 133
# 3127 NAE  FC  VFD  MAIN REQ 131
# 3128 NAE  FC  VFD  RUN ENB 132
# 3129 NAE  FC  VFD  VFD STS 135
# 3130 NAE  FC  VFD  HAND AUTO 134
# 3131 NAE  FC  VFD  FLT STS 136
# 3132 NAE  FC  VFD  ALARM 133
# 3133 NAE  FC  VFD  MAIN REQ 131
# 3134 NAE  FC  VFD  RUN ENB 132
# 3135 NAE  FC  VFD  VFD STS 135
# 3136 NAE  FC  VFD  HAND AUTO 134
# 3137 NAE  FC  VFD  FLT STS 136
# 3138 NAE  FC  VFD  ALARM 133
# 3139 NAE  FC  VFD  MAIN REQ 131
# 3140 NAE  FC  VFD  RUN ENB 132
# 3141 NAE  FC  VFD  VFD STS 135
# 3142 NAE  FC  VFD  HAND AUTO 134
# 3143 NAE  FC  VFD  FLT STS 136
# 3144 NAE  FC  VFD  ALARM 133
# 3145 NAE  FC  VFD  MAIN REQ 131
# 3146 NAE  FC  VFD  RUN ENB 132
# 3147 NAE  FC  VFD  VFD STS 135
# 3148 NAE  FC  VFD  HAND AUTO 134
# 3149 NAE  FC  VFD  FLT STS 136
# 3150 NAE  FC  VFD  ALARM 133
# 3151 NAE  FC  VFD  MAIN REQ 131
# 3152 NAE  FC  VFD  RUN ENB 132
# 3153 NAE  FC  VFD  VFD STS 135
# 3154 NAE  FC  VFD  HAND AUTO 134
# 3155 NAE  FC  VFD  FLT STS 136
# 3156 NAE  FC  VFD  ALARM 133
# 3157 NAE  FC  VFD  MAIN REQ 131
# 3158 NAE  FC  VFD  RUN ENB 132
# 3159 NAE  FC  VFD  VFD STS 135
# 3160 NAE  FC  VFD  HAND AUTO 134
# 3161 NAE  FC  VFD  FLT STS 136
# 3162 NAE  FC  VFD  ALARM 133
# 3163 NAE  FC  VFD  MAIN REQ 131
# 3164 NAE  FC  VFD  RUN ENB 132
# 3165 NAE  FC  VFD  VFD STS 135
# 3166 NAE  FC  VFD  HAND AUTO 134
# 3167 NAE  FC  VFD  FLT STS 136
# 3168 NAE  FC  VFD  ALARM 133
# 3169 NAE  FC  VFD  MAIN REQ 131
# 3170 NAE  FC  VFD  RUN ENB 132
# 3171 NAE  FC  VFD  VFD STS 135
# 3172 NAE  FC  VFD  HAND AUTO 134
# 3173 NAE  FC  VFD  FLT STS 136
# 3174 NAE  FC  VFD  ALARM 133
# 3175 NAE  FC  VFD  MAIN REQ 131
# 3176 NAE  FC  VFD  RUN ENB 132
# 3177 NAE  FC  VFD  VFD STS 135
# 3178 NAE  FC  VFD  HAND AUTO 134
# 3179 NAE  FC  VFD  FLT STS 136
# 3180 NAE  FC  VFD  ALARM 133
# 3181 NAE  FC  VFD  MAIN REQ 131
# 3182 NAE  Programming Zone Load Shed BONNER th Floor Lab Load Shed 140
# 3183 NAE  FC  EFX VMA  OCC STS 77
# 3184 NAE  FC  AH VMA  OCC CMD 72
# 3185 NAE  FC  AH VMA  OCC STS 76
# 3186 NAE  FC  EFX VMA  OCC STS 77
# 3187 NAE  FC  AH VMA  OCC CMD 72
# 3188 NAE  FC  AH VMA  OCC STS 76
# 3189 NAE  FC  AHX VMA  OCC CMD 72
# 3190 NAE  FC  AHX VMA  OCC STS 76
# 3191 NAE  FC  EFX VMA  OCC STS 77
# 3192 NAE  FC  AH VMA  OCC CMD 72
# 3193 NAE  FC  AH VMA  OCC STS 76
# 3194 NAE  FC  EFX VMA  OCC STS 77
# 3195 NAE  FC  AH VMA  OCC CMD 72
# 3196 NAE  FC  AH VMA  OCC STS 76
# 3197 NAE  FC  EFX VMA  OCC STS 77
# 3198 NAE  FC  AH FEC  OCC CMD 72
# 3199 NAE  FC  AH FEC  OCC STS 77
# 3200 NAE  FC  AH VMA  OCC CMD 72
# 3201 NAE  FC  AH VMA  OCC STS 76
# 3202 NAE  FC  EFX VMA  OCC STS 77
# 3203 NAE  FC  AH VMA  OCC CMD 72
# 3204 NAE  FC  AH VMA  OCC STS 76
# 3205 NAE  FC  EFX VMA  OCC STS 77
# 3206 NAE  FC  AH VMA  OCC CMD 72
# 3207 NAE  FC  AH VMA  OCC STS 76
# 3208 NAE  FC  EFX VMA  OCC STS 77
# 3209 NAE  FC  AH VMA  OCC CMD 72
# 3210 NAE  FC  AH VMA  OCC STS 76
# 3211 NAE  FC  EFX VMA  OCC STS 77
# 3212 NAE  Programming Zone Load Shed BONNER thFlr Office Load Shed 70

# %%
#read ground truth sensor types
import csv
building = 'bonner'
ground_truth_list = []
with open('metadata/'+building+'_sensor_types.csv') as ground_truth_file:
    csv_reader = csv.DictReader(ground_truth_file)
    for row in csv_reader:
        ground_truth_list.append(row)
sensor_type_map = {s['source_id']:s['sensor_type'] for s in ground_truth_list}

# %%
# Merges the clusters formed by hierarchical clustering based on "description" tag. 
equip_desc_map = {}
sensor_abbrvs = [s['jci_name'].split('.')[-1].lower() if '.' in s['jci_name'] else s['jci_name'] for s in ground_truth_list]
#sensor_abbrvs = [re.sub('[^a-z ]', '', s) for s in sensor_abbrvs]

for k,v in equip_map.iteritems():
    #print v
    desc_list = [s['description'].lower() for s in v['sensors']]
    desc_list = [re.sub('[^a-z ]', '', d) for d in desc_list]
    desc_list = [sensor_abbrvs[i] if d == '' else d for i,d in enumerate(desc_list)]
    if len(set(desc_list)) == 1:
        if desc_list[0] in equip_desc_map and desc_list[0] != '':
            equip_desc_map[desc_list[0]]['sensors'] += v['sensors']
            equip_desc_map[desc_list[0]]['sensor_ids'] += v['sensor_ids']
        elif desc_list[0] == '':
            equip_desc_map[k] = v
        else:
            equip_desc_map[desc_list[0]] = v
    else:
        equip_desc_map[k] = v
    
#print "merged cluster:", len(equip_desc_map)
# Out:
# merged cluster: 195

# %%
#get ground truth set
#equip_map = equip_desc_map #Uncomment for using merged clusters
# Manually label say 10 clusters and hence multiple sensors. 
import random
num_manual_labels = 10
sensor_labels = []
sensor_bow = []
labeled_equip_keys = []
equip_cluster_lens = {k:len(v['sensors']) for k,v in equip_map.iteritems()}
sorted_equip_keys = sorted(equip_cluster_lens.items(), key=operator.itemgetter(1), reverse=True)
for i in range(num_manual_labels):
#for c_id in equip_map.keys()[:num_manual_labels]:
    c_id = random.choice(equip_map.keys())
    #c_id = sorted_equip_keys[i][0]
    labeled_equip_keys.append(c_id)
    for ix,i in enumerate(equip_map[c_id]['sensor_ids']):
            sensor_bow.append(bow_array[i])
            source_id = sensor_list[i]['source_id']
            sensor_labels.append(sensor_type_map[source_id])
sensor_bow = np.array(sensor_bow)
sensor_labels = np.array(sensor_labels)
# Out:
# (52, 402)
# (52,)

# %%
#learn a model
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import OneClassSVM
from sklearn.mixture import GMM
from sklearn.mixture import DPGMM
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier
from sklearn.naive_bayes import MultinomialNB
le = LabelEncoder()
le.fit(sensor_labels)
#print list(le.classes_)
train_labels = le.transform(sensor_labels)
model = RandomForestClassifier(n_estimators=400, random_state=0)
model.fit(sensor_bow,sensor_labels)
#model.fit(sensor_bow)
# Out:
# ['actual heating setpoint', 'call for fan to run', 'cooling demand', 'exhaust fan start stop', 'exhaust fan status', 'power in kw', 'push to test button', 'supply air temperature reset high setpoint', 'supply air temperature reset low setpoint']
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=400, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
def apply_model_on_all_clusters( ): # model, T_low, T_high, ....
    # This method uses global variables including model, T_low, T_high and several others. 
    # Goal: apply model on all clusters and determine correctness of "confident predictions" 
    # and manually label "very low confidence" ones 

    global sensor_labels
    global sensor_bow 
    global labeled_equip_keys 
    
    # Iteratively apply Random Forest to label new sensors 
    change_thresholds = True 
    n_wrong_confident_sensor_pred = 0
    sensor_bow = list(sensor_bow)
    sensor_labels = list(sensor_labels) 
    n_high_confidence_sensors = 0
    n_manually_labeled_thisepoch = 0 # epoch = whatever happens after (re-) training RF models

    for p in equip_map.keys(): # for each cluster 
    #for p in sorted_equip_keys:
        #p = p[0]

        # Escape if already labeled. 
        if p in labeled_equip_keys:
            continue


        # Get sensors from this cluster. 
        sample_bow = []
        for k in equip_map[p]['sensor_ids']:
            sample_bow.append(bow_array[k])
        sample_bow = np.array(sample_bow)


        # Apply trained model: 
        confidence = model.predict_proba(sample_bow)
        prediction_label = model.predict(sample_bow)
        # Get overall max confidence for any sensor in cluster: 
        max_c = 0
        for c in confidence:
            max_c = max(np.append(c,[max_c]))


        # Compare with Thresholds. 
        flag = 0    
        if max_c < T_low:
            flag = 1
        if max_c > T_high:
            flag = 2        

        if flag==1: 
            n_manually_labeled_thisepoch+=1 

        
        # Handle the cluster beyond threshold: 
        if flag>0: 
            change_thresholds = False 
            labeled_equip_keys.append(p)  

            # For each sensor in this cluster: 
            for k in range(len(equip_map[p]['sensors'])):  
                sourceid = equip_map[p]['sensors'][k]['source_id']
                true_type = sensor_type_map[sourceid] 
                pred_type = prediction_label[k]              

                if flag==2: 
                    n_high_confidence_sensors+=1
                    if pred_type != true_type: 
                        n_wrong_confident_sensor_pred+=1 

                    # append these sensors into labeled ones (with possibly wrong labels): 
                    sensor_bow.append(bow_array[equip_map[p]['sensor_ids'][k]]) 
                    sensor_labels.append(pred_type) 

                if flag==1:                 
                    
                    # append these sensors into labeled ones (with ground truth): 
                    sensor_bow.append(bow_array[equip_map[p]['sensor_ids'][k]]) 
                    sensor_labels.append(true_type) 

            break
        #sensor_bow = np.array(sensor_bow)
        #sensor_labels = np.array(sensor_labels)
        #model.fit(sensor_bow, sensor_labels)
        
    return n_manually_labeled_thisepoch, n_wrong_confident_sensor_pred, n_high_confidence_sensors, len(sensor_labels), 100.0*len(sensor_labels)/len(bow_array),change_thresholds,len(bow_array)-len(sensor_labels)   
    # return __  , __ , __ , num labeled sensors , % labeled sensors, change_thresholds, num_sensors_in_gray

# %%
# Iteratively train RF model and call the method to apply it on all clusters. 
# When method asks us to change thresholds, then we do so. 
# Otherwise we re-train RF and try catch more sensors. 
# We also record the number of correct sensors in each iteration, the manual effort in each iteration etc. 

#print equip_map.keys() 
#print labeled_equip_keys 
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=400, random_state=0)
model.fit(sensor_bow,sensor_labels) 

num_sensors_in_gray=100

T_low = 0.1
T_high = 0.95 
thresholds = [ (0.1,0.95), (0.1,0.9) , (0.15,0.9), (0.15,0.85), (0.2,0.85), (0.25,0.85), (0.3,0.85), (0.35,0.85), (0.4,0.85), (0.45,0.85), (0.5,0.85), (0.55,0.85), (0.6,0.85), (0.65,0.85), (0.7,0.85), (0.75,0.85), (0.8,0.85), (0.849999999,0.85) ] 
#thresholds = [ (0.1,0.9) , (0.15,0.9), (0.15,0.85), (0.2,0.85), (0.25,0.85), (0.3,0.85), (0.35,0.85), (0.4,0.85), (0.45,0.85), (0.45,0.8),(0.5,0.8), (0.55,0.8), (0.6,0.8), (0.65,0.8), (0.7,0.8), (0.75,0.8), (0.7999999,0.8) ] 
#thresholds = [ (0.1,0.7) , (0.25,0.7), (0.3,0.7), (0.3,0.7), (0.35,0.7), (0.4,0.7), (0.4,0.65),(0.45,0.65), (0.5,0.65), (0.5,0.6), (0.55,0.6), (0.5999999,0.6)] 

thresh_count=0 

# Start iterations: 
n_manual_lab_clusters_iter = [10 ]
n_sensors_covered_iter = [len(sensor_labels) ] 

while num_sensors_in_gray>0: 
    T_low,T_high = thresholds[thresh_count] 
    
    # Re-train model: 
    model.fit(sensor_bow,sensor_labels) 
    
    # Use model to label clusters/sensors: 
    n_manually_labeled_thisepoch, n_wrong_confident_sensor_pred, n_high_confidence_sensors, n_sens_covered, perc_coverage,change_thresholds,num_sensors_in_gray = apply_model_on_all_clusters()        
    print n_manually_labeled_thisepoch, n_wrong_confident_sensor_pred, n_high_confidence_sensors, n_sens_covered, perc_coverage,change_thresholds,num_sensors_in_gray  
    n_manual_lab_clusters_iter.append(n_manual_lab_clusters_iter[-1] + n_manually_labeled_thisepoch) 
    n_sensors_covered_iter.append(n_sens_covered) 
    
    if change_thresholds: 
        thresh_count+=1 
        print T_low, T_high
# Out:
# 0 0 64 116 3.6103330221 False 3097
# 0 0 46 162 5.04201680672 False 3051
# 0 0 0 162 5.04201680672 True 3051
# 0.1 0.95
# 0 0 0 162 5.04201680672 True 3051
# 0.1 0.9
# 0 0 0 162 5.04201680672 True 3051
# 0.15 0.9
# 0 0 126 288 8.96358543417 False 2925
# 0 0 33 321 9.99066293184 False 2892
# 0 0 87 408 12.6984126984 False 2805
# 0 0 3 411 12.79178338 False 2802
# 0 0 0 411 12.79178338 True 2802
# 0.15 0.85
# 1 0 0 417 12.9785247432 False 2796
# 1 0 0 420 13.0718954248 False 2793
# 1 0 0 437 13.6009959539 False 2776
# 0 0 16 453 14.0989729225 False 2760
# 0 0 4 457 14.2234671646 False 2756
# 1 0 0 498 15.4995331466 False 2715
# 0 0 39 537 16.7133520075 False 2676
# 0 0 22 559 17.3980703392 False 2654
# 1 0 0 573 17.8338001867 False 2640
# 1 0 0 629 19.5767195767 False 2584
# 0 0 58 687 21.3818860878 False 2526
# 1 0 0 720 22.4089635854 False 2493
# 1 0 0 765 23.8095238095 False 2448
# 0 5 5 770 23.9651416122 False 2443
# 0 12 12 782 24.3386243386 False 2431
# 1 0 0 793 24.6809835045 False 2420
# 1 0 0 794 24.712107065 False 2419
# 1 0 0 795 24.7432306256 False 2418
# 1 0 0 806 25.0855897915 False 2407
# 0 2 59 865 26.9218798631 False 2348
# 0 2 2 867 26.9841269841 False 2346
# 0 45 48 915 28.4780578898 False 2298
# 0 45 45 960 29.8786181139 False 2253
# 0 0 167 1127 35.0762527233 False 2086
# 0 0 2 1129 35.1384998444 False 2084
# 0 0 86 1215 37.8151260504 False 1998
# 0 0 1 1216 37.846249611 False 1997
# 0 0 39 1255 39.0600684718 False 1958
# 0 0 2 1257 39.1223155929 False 1956
# 0 0 1 1258 39.1534391534 False 1955
# 1 0 0 1263 39.3090569561 False 1950
# 1 0 0 1327 41.3009648304 False 1886
# 0 0 46 1373 42.732648615 False 1840
# 0 0 1 1374 42.7637721755 False 1839
# 1 0 0 1392 43.3239962652 False 1821
# 1 0 0 1414 44.0087145969 False 1799
# 1 0 0 1415 44.0398381575 False 1798
# 1 0 0 1426 44.3821973234 False 1787
# 1 0 0 1427 44.4133208839 False 1786
# 1 0 0 1438 44.7556800498 False 1775
# 1 0 0 1455 45.2847805789 False 1758
# 0 0 136 1591 49.5175848117 False 1622
# 0 0 15 1606 49.9844382197 False 1607
# 0 0 40 1646 51.2293806411 False 1567
# 0 0 18 1664 51.7896047308 False 1549
# 0 0 13 1677 52.1942110177 False 1536
# 1 0 0 1680 52.2875816993 False 1533
# 0 53 148 1828 56.8938686586 False 1385
# 0 47 47 1875 58.3566760037 False 1338
# 0 16 16 1891 58.8546529723 False 1322
# 0 4 4 1895 58.9791472144 False 1318
# 0 16 16 1911 59.477124183 False 1302
# 0 0 24 1935 60.2240896359 False 1278
# 0 0 67 2002 62.3093681917 False 1211
# 0 0 1 2003 62.3404917523 False 1210
# 1 0 0 2004 62.3716153128 False 1209
# 1 0 0 2008 62.4961095549 False 1205
# 1 0 0 2011 62.5894802365 False 1202
# 1 0 0 2012 62.6206037971 False 1201
# 1 0 0 2016 62.7450980392 False 1197
# 0 0 14 2030 63.1808278867 False 1183
# 1 0 0 2031 63.2119514472 False 1182
# 1 0 0 2032 63.2430750078 False 1181
# 1 0 0 2037 63.3986928105 False 1176
# 1 0 0 2038 63.429816371 False 1175
# 1 0 0 2039 63.4609399315 False 1174
# 1 0 0 2040 63.4920634921 False 1173
# 1 0 0 2042 63.5543106131 False 1171
# 1 0 0 2043 63.5854341737 False 1170
# 1 0 0 2046 63.6788048553 False 1167
# 1 0 0 2047 63.7099284158 False 1166
# 0 0 19 2066 64.301276066 False 1147
# 1 0 0 2069 64.3946467476 False 1144
# 1 0 0 2072 64.4880174292 False 1141
# 0 0 13 2085 64.8926237162 False 1128
# 1 0 0 2090 65.0482415188 False 1123
# 1 0 0 2091 65.0793650794 False 1122
# 1 0 0 2092 65.1104886399 False 1121
# 1 0 0 2093 65.1416122004 False 1120
# 1 0 0 2096 65.234982882 False 1117
# 0 0 19 2115 65.8263305322 False 1098
# 0 0 13 2128 66.2309368192 False 1085
# 1 0 0 2129 66.2620603797 False 1084
# 1 0 0 2130 66.2931839402 False 1083
# 1 0 0 2154 67.0401493931 False 1059
# 1 0 0 2156 67.1023965142 False 1057
# 0 8 12 2168 67.4758792406 False 1045
# 0 1 1 2169 67.5070028011 False 1044
# 0 4 4 2173 67.6314970433 False 1040
# 0 1 1 2174 67.6626206038 False 1039
# 0 1 1 2175 67.6937441643 False 1038
# 0 1 1 2176 67.7248677249 False 1037
# 1 0 0 2180 67.849361967 False 1033
# 0 0 1 2181 67.8804855275 False 1032
# 0 0 0 2181 67.8804855275 True 1032
# 0.2 0.85
# 1 0 0 2199 68.4407096172 False 1014
# 1 0 0 2202 68.5340802988 False 1011
# 1 0 0 2213 68.8764394647 False 1000
# 1 0 0 2224 69.2187986306 False 989
# 1 0 0 2225 69.2499221911 False 988
# 1 0 0 2242 69.7790227202 False 971
# 1 0 0 2253 70.1213818861 False 960
# 1 0 0 2254 70.1525054466 False 959
# 1 0 0 2255 70.1836290072 False 958
# 1 0 0 2294 71.397447868 False 919
# 0 0 41 2335 72.67351385 False 878
# 1 0 0 2350 73.140367258 False 863
# 0 0 123 2473 76.9685652039 False 740
# 0 0 40 2513 78.2135076253 False 700
# 0 0 17 2530 78.7426081544 False 683
# 0 0 18 2548 79.302832244 False 665
# 1 0 0 2550 79.3650793651 False 663
# 1 0 0 2564 79.8008092126 False 649
# 1 0 0 2597 80.8278867102 False 616
# 0 0 38 2635 82.0105820106 False 578
# 0 0 4 2639 82.1350762527 False 574
# 0 0 20 2659 82.7575474634 False 554
# 1 0 0 2663 82.8820417056 False 550
# 0 0 3 2666 82.9754123872 False 547
# 1 0 0 2667 83.0065359477 False 546
# 1 0 0 2668 83.0376595082 False 545
# 1 0 0 2696 83.9091192032 False 517
# 0 0 88 2784 86.6479925303 False 429
# 0 0 30 2814 87.5816993464 False 399
# 0 0 2 2816 87.6439464675 False 397
# 0 0 26 2842 88.4531590414 False 371
# 1 0 0 2843 88.4842826019 False 370
# 1 0 0 2844 88.5154061625 False 369
# 1 0 0 2845 88.546529723 False 368
# 0 2 2 2847 88.6087768441 False 366
# 0 0 10 2857 88.9200124494 False 356
# 1 0 0 2858 88.95113601 False 355
# 1 0 0 2862 89.0756302521 False 351
# 0 0 0 2862 89.0756302521 True 351
# 0.25 0.85
# 1 0 0 2863 89.1067538126 False 350
# 1 0 0 2865 89.1690009337 False 348
# 1 0 0 2881 89.6669779023 False 332
# 0 0 13 2894 90.0715841892 False 319
# 1 0 0 2899 90.2272019919 False 314
# 1 0 0 2909 90.5384375973 False 304
# 1 0 0 2919 90.8496732026 False 294
# 1 0 0 2933 91.2854030501 False 280
# 1 0 0 2935 91.3476501712 False 278
# 1 0 0 2939 91.4721444133 False 274
# 0 10 14 2953 91.9078742608 False 260
# 0 0 4 2957 92.032368503 False 256
# 1 0 0 2961 92.1568627451 False 252
# 1 0 0 2965 92.2813569872 False 248
# 0 10 14 2979 92.7170868347 False 234
# 1 0 0 2993 93.1528166822 False 220
# 1 0 0 2994 93.1839402428 False 219
# 1 0 0 2997 93.2773109244 False 216
# 1 0 0 3000 93.370681606 False 213
# 1 0 0 3002 93.432928727 False 211
# 0 0 4 3006 93.5574229692 False 207
# 1 0 0 3009 93.6507936508 False 204
# 1 0 0 3010 93.6819172113 False 203
# 0 0 19 3029 94.2732648615 False 184
# 1 0 0 3030 94.304388422 False 183
# 1 0 0 3031 94.3355119826 False 182
# 0 0 13 3044 94.7401182695 False 169
# 0 0 10 3054 95.0513538749 False 159
# 1 0 0 3064 95.3625894802 False 149
# 1 0 0 3078 95.7983193277 False 135
# 0 0 10 3088 96.1095549331 False 125
# 1 0 0 3102 96.5452847806 False 111
# 1 0 0 3116 96.9810146281 False 97
# 0 0 10 3126 97.2922502334 False 87
# 1 0 0 3139 97.6968565204 False 74
# 1 0 0 3152 98.1014628073 False 61
# 0 0 10 3162 98.4126984127 False 51
# 1 0 0 3165 98.5060690943 False 48
# 0 0 0 3165 98.5060690943 True 48
# 0.3 0.85
# 1 0 0 3204 99.7198879552 False 9
# 0 10 51 3255 101.307189542 False -42

# %%
# This code uses regular expressions to map descriptions (and if needed, jci_name) to ground truth 
# Goal: Get a manual effort (in mapping either of above to ground truth) to coverage 

desc_list=[] 
jc_names_list=[] 
sensor_info = {} 
for s in sensor_list: 
    sid = s['source_id'] 
    sensor_info[sid]={} 
    d = s['description'].lower() 
    d = ''.join([i for i in d if not i.isdigit()]) #remove digits 
    d = re.sub(r"[^\w' ]", "",  d ) # remove special chars 
    d = ' '.join(d.split()) #remove extra spaces 
    sensor_info[sid]['desc'] = d 
    desc_list.append(d)     
    
    j = s['jci_name'].split('.')[-1] 
    sensor_info[sid]['jci'] = j 
    jc_names_list.append(j)  
    sensor_info[sid]['figuredout'] = False 
    
manualeffort=[0] 
coveredsensors=[0] 
desc_map = {}
jci_map = {} 

for s in sensor_list: 
    sid = s['source_id'] 
    if sensor_info[sid]['figuredout']==True: continue # If label known, skip. 
        
    # Info about this sensor: 
    gt = sensor_type_map[ s['source_id'] ]  # ground truth 
    d = s['description'].lower() 
    d = ''.join([i for i in d if not i.isdigit()]) #remove digits 
    d = re.sub(r"[^\w' ]", "",  d ) # remove special chars 
    d = ' '.join(d.split()) #remove extra spaces 
    j = s['jci_name'].split('.')[-1] 

    
    if not d =="": 
        if not d in desc_map: 
            manualeffort.append(manualeffort[-1]+1) 
            desc_map[d] = gt 
            jci_map[j] = gt 
            sensor_info[sid]['figuredout']=True 
            # Check how many it catches: 
            numcatches=0
            for s2 in sensor_list: 
                sid2 = s2['source_id'] 
                if sensor_info[sid2]['figuredout']==False and (sensor_info[sid2]['desc']==d   or sensor_info[sid2]['jci']==j): 
                    sensor_info[sid2]['figuredout']=True
                    numcatches+=1 
            coveredsensors.append(coveredsensors[-1] + numcatches) 
            
    else: 
        if not j in jci_map: 
            manualeffort.append(manualeffort[-1]+1) 
            jci_map[j] = gt 
            sensor_info[sid]['figuredout']=True 
            # Check how many it catches: 
            numcatches=0
            for s2 in sensor_list: 
                sid2 = s2['source_id'] 
                if sensor_info[sid2]['figuredout']==False and sensor_info[sid2]['jci']==j: 
                    sensor_info[sid2]['figuredout']=True
                    numcatches+=1 
            coveredsensors.append(coveredsensors[-1] + numcatches) 
            
            
            
    
# Just checking. 
for s in sensor_list: 
    sid = s['source_id'] 
    if sensor_info[sid]['figuredout']==False: 
        print sid 


        

# Plot the manual effort vs coverage for Regex based approach. 
plt.plot(manualeffort, coveredsensors, 'ro')
plt.xticks(fontsize=20)
plt.yticks(fontsize=15)
plt.ylabel('# points covered', fontsize=20)
plt.xlabel('Manual inputs', fontsize=20)
plt.tight_layout()

plt.xticks(np.arange(0, max(manualeffort)+1, 75.))

plt.savefig("BonnersensorsREGEXManualVsCoverage.pdf",bbox_inches='tight',dpi=150)


len(set(jc_names_list))
